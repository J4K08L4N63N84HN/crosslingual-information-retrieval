# %% [markdown]
# # Preprocessing and Feature Creation

# %% [markdown]
# In this notebook we import the data, preprocess the data and create features for supervised and unsupervised cross-lingual-information retrieval models.

# %% [markdown]
# ## I. Import Data

# %% [markdown]
# In this section we import the English and German europarl datasets and combine them into a parallel sentence translation dataframe.

# %%
from src.data.preprocessing_class import PreprocessingEuroParl

# %%
parallel_sentences = PreprocessingEuroParl(sentence_data_source='../data/external/europarl-v7.de-en.en',
                 sentence_data_target='../data/external/europarl-v7.de-en.de')

# %%
parallel_sentences.dataframe
# Out:
#                                           text_source  \
# 1   I declare resumed the session of the European ...
# 2   Although, as you will have seen, the dreaded '...
# 3   You have requested a debate on this subject in...
# 4   In the meantime, I should like to observe a mi...
# 5      Please rise, then, for this minute' s silence.
# ..                                                ...
# 95                   There was a vote on this matter.
# 96  As I recall, the outcome of this vote was 422 ...
# 97  This means that all the Groups with the except...
# 98     All of the others were of a different opinion.
# 99                             That was the decision.
#
#                                           text_target
# 1   Ich erkläre die am Freitag, dem 17. Dezember u...
# 2   Wie Sie feststellen konnten, ist der gefürchte...
# 3   Im Parlament besteht der Wunsch nach einer Aus...
# 4   Heute möchte ich Sie bitten - das ist auch der...
# 5   Ich bitte Sie, sich zu einer Schweigeminute zu...
# ..                                                ...
# 95            Es gab eine Abstimmung zu diesem Punkt.
# 96  Diese Abstimmung ist meiner Erinnerung nach so...
# 97  Das heißt, alle Fraktionen, mit Ausnahme der F...
# 98                Alle anderen waren anderer Meinung.
# 99                              Das war der Beschluß.
#
# [99 rows x 2 columns]

# %% [markdown]
# ## II. Preprocess data

# %% [markdown]
# In this section we preprocess the parallel sentence data.

# %%
import spacy
from nltk.corpus import stopwords
from textblob import TextBlob as textblob_source
from textblob_de import TextBlobDE as textblob_target
import en_core_web_sm
import de_core_news_sm

# %%
stopwords_source = stopwords.words('english')
stopwords_target = stopwords.words('german')
nlp_source = en_core_web_sm.load()
nlp_target = de_core_news_sm.load()
embedding_matrix_source = "../data/interim/proc_b_src_emb.p"
embedding_dictionary_source =  "../data/interim/proc_b_src_word.p"
embedding_matrix_target = "../data/interim/proc_b_trg_emb.p"
embedding_dictionary_target =  "../data/interim/proc_b_trg_word.p"

# %%
parallel_sentences.preprocess_sentences_source(stopwords_source, nlp_source, textblob_source,
                                               embedding_matrix_source, embedding_dictionary_source)
# Out:
# /Users/jakob/opt/miniconda3/envs/crosslingual-information-retrieval/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
print(parallel_sentences.dataframe.columns[1:70])
# Out:
# Index(['text_target', 'token_preprocessed_source',
#        'number_punctuations_total_source', 'number_words_source',
#        'number_unique_words_source', 'number_!_source', 'number_"_source',
#        'number_#_source', 'number_$_source', 'number_%_source',
#        'number_&_source', 'number_'_source', 'number_(_source',
#        'number_)_source', 'number_*_source', 'number_+_source',
#        'number_,_source', 'number_-_source', 'number_._source',
#        'number_/_source', 'number_:_source', 'number_;_source',
#        'number_<_source', 'number_=_source', 'number_>_source',
#        'number_?_source', 'number_@_source', 'number_[_source',
#        'number_\_source', 'number_]_source', 'number_^_source',
#        'number___source', 'number_`_source', 'number_{_source',
#        'number_|_source', 'number_}_source', 'number_~_source',
#        'number_characters_source', 'number_ADJ_source', 'number_ADP_source',
#        'number_ADV_source', 'number_AUX_source', 'number_CONJ_source',
#        'number_CCONJ_source', 'number_DET_source', 'number_INTJ_source',
#        'number_NOUN_source', 'number_NUM_source', 'number_PRT_source',
#        'number_PRON_source', 'number_PROPN_source', 'number_SCONJ_source',
#        'number_SYM_source', 'number_VERB_source', 'number_X_source',
#        'number_Pres_source', 'number_Past_source', 'number__source',
#        'score_polarity_source', 'score_subjectivity_source',
#        'number_stopwords_source', 'list_named_entities_source',
#        'sentence_embedding_source', 'token_preprocessed_target',
#        'number_punctuations_total_target', 'number_words_target',
#        'number_unique_words_target', 'number_!_target', 'number_"_target'],
#       dtype='object')

# %%
parallel_sentences.preprocess_sentences_target(stopwords_source,nlp_source, textblob_source, 
                                               embedding_matrix_target, embedding_dictionary_target)
# Out:
# /Users/jakob/opt/miniconda3/envs/crosslingual-information-retrieval/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
parallel_sentences.dataframe.columns
# Out:
# Index(['text_source', 'text_target', 'token_preprocessed_source',
#        'number_punctuations_total_source', 'number_words_source',
#        'number_unique_words_source', 'number_!_source', 'number_"_source',
#        'number_#_source', 'number_$_source',
#        ...
#        'number_VERB_target', 'number_X_target', 'number_Pres_target',
#        'number_Past_target', 'number__target', 'score_polarity_target',
#        'score_subjectivity_target', 'number_stopwords_target',
#        'list_named_entities_target', 'sentence_embedding_target'],
#       dtype='object', length=126)

# %% [markdown]
# ## II. Create sentence based features

# %% [markdown]
# In this section we create features for our model, that are sentence based and should be created before the text is preprocessed.

# %%
from src.features.feature_generation_class import FeatureGeneration

# %%
features = FeatureGeneration(parallel_sentences.dataframe)

# %%
features.feature_generation()

# %%
features.feature_dataframe
# Out:
#     number_punctuations_total_difference  number_words_difference  \
# 1                                     -2                       -8
# 2                                      1                        6
# 3                                      2                       -7
# 4                                      1                       14
# 5                                      2                      -11
# ..                                   ...                      ...
# 95                                     0                       -7
# 96                                     0                      -33
# 97                                    -1                       10
# 98                                     0                       11
# 99                                     0                        1
#
#     number_unique_words_difference  number_!_difference  number_"_difference  \
# 1                               -4                    0                    0
# 2                               -6                    0                   -2
# 3                               -4                    0                    0
# 4                               -8                    0                    0
# 5                               -1                    0                    0
# ..                             ...                  ...                  ...
# 95                              -3                    0                    0
# 96                              -1                    0                    0
# 97                              -4                    0                    0
# 98                               3                    0                    0
# 99                              -1                    0                    0
#
#     number_#_difference  number_$_difference  number_%_difference  \
# 1                     0                    0                    0
# 2                     0                    0                    0
# 3                     0                    0                    0
# 4                     0                    0                    0
# 5                     0                    0                    0
# ..                  ...                  ...                  ...
# 95                    0                    0                    0
# 96                    0                    0                    0
# 97                    0                    0                    0
# 98                    0                    0                    0
# 99                    0                    0                    0
#
#     number_&_difference  number_'_difference  ...  number_SCONJ_difference  \
# 1                     0                    0  ...                        1
# 2                     0                    2  ...                        1
# 3                     0                    0  ...                        0
# 4                     0                    1  ...                        0
# 5                     0                    1  ...                        0
# ..                  ...                  ...  ...                      ...
# 95                    0                    0  ...                        0
# 96                    0                    0  ...                        0
# 97                    0                    0  ...                        2
# 98                    0                    0  ...                        0
# 99                    0                    0  ...                        0
#
#     number_SYM_difference  number_VERB_difference  number_X_difference  \
# 1                       0                       1                    0
# 2                       0                       5                    0
# 3                       0                      -2                    0
# 4                       0                       2                    0
# 5                       0                       1                    0
# ..                    ...                     ...                  ...
# 95                      0                       0                    0
# 96                      0                       0                    0
# 97                      0                       1                   -1
# 98                      0                      -1                    0
# 99                      0                       0                    0
#
#     number_Pres_difference  number_Past_difference  number__difference  \
# 1                        0                       0                   0
# 2                        0                       0                   0
# 3                        0                       0                   0
# 4                        0                       0                   0
# 5                        0                       0                   0
# ..                     ...                     ...                 ...
# 95                       0                       0                   0
# 96                       0                       0                   0
# 97                       0                       0                   0
# 98                       0                       0                   0
# 99                       0                       0                   0
#
#     score_polarity_difference  score_subjectivity_difference  \
# 1                    0.433939                       0.624242
# 2                   -0.466667                       0.566667
# 3                   -0.122222                       0.144444
# 4                   -0.208333                       0.458333
# 5                    0.000000                       0.000000
# ..                        ...                            ...
# 95                   0.000000                       0.000000
# 96                  -0.200000                       0.100000
# 97                   0.000000                       1.000000
# 98                   0.000000                       0.600000
# 99                   0.000000                       0.000000
#
#     number_stopwords_difference
# 1                            16
# 2                            17
# 3                             6
# 4                            26
# 5                             4
# ..                          ...
# 95                            0
# 96                            0
# 97                           10
# 98                            8
# 99                            5
#
# [99 rows x 59 columns]

# %% [markdown]
# ## III. Preprocess data for token based features

# %% [markdown]
# ## IV. Create token based features

# %%
sentence = "This is a sentence!"

# %%
[word for word in sentence]

# %%
len([word for word in sentence])
