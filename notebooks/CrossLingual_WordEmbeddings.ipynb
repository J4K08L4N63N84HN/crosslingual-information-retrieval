# %% [markdown]
# # Induce and Evaluate Proc, Proc-B and VecMap
#
# This Notebook will induce all CLWE used in this project (Proc, Proc-B and VecMap) and will directly evaluate each method on the BLI task. We evaluate on 6 language pairs: EN-DE, EN-PL, EN-NL, EN-FI, EN-RU, EN-IT. At the bottom of the notebook, you can create subsets of the translation dictionary (e.g. for creating 500 unique source words translations)

# %%
#! pip3 install torch==1.5.0 transformers==3.4.0
#! pip install faiss-gpu cudatoolkit=10.0 -c pytorch

# %%
import sys
import os
sys.path.append(os.path.dirname((os.path.abspath(''))))
from src.cross_lingual_embeddings.pipeline_clwe_induction import clew_induction
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. EN-DE

# %%
path_source_language = "../data/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "../data/monolingual_embedding/fasttext.wiki.de.300.vocab_200K.vec"

train_translation_dict_path = "../data/translation_dict/en-de.0-5000.txt"
train_translation_dict_1k_path = "../data//translation_dict/en-de.0-500.txt"
test_translation_dict_path = "../data/translation_dict/en-de.5000-6500.txt"
new_test_translation_path = "../data/translation_dict/yacle.test.freq.cutoff.en-de.tsv"

clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                   train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                   "en_de", number_tokens=100000, save_embedding=True)
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 3660
# New Dictionary Size: 3561
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 14677
# Length of dictionary after pruning: 14420
#
#
# Number of Test Translations: 3561/3561
# P@1: 0.2990732940185341
# P@5: 0.5810165683796686
# P@10: 0.6590845268183094
#
#
# MRR: 0.4227324011221896
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1677
# Length of dictionary after pruning: 1666
#
#
# Number of Test Translations: 3561/3561
# P@1: 0.2038753159224937
# P@5: 0.44566133108677336
# P@10: 0.5313114293737714
#
#
# MRR: 0.3137714125427455
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1677
# Length of Original dictionary: 1677
# Length of dictionary after pruning: 1666
# Length of new dictionary: 2515
# Length of Original dictionary: 2515
# Length of dictionary after pruning: 2515
# Length of new dictionary: 3772
# Length of Original dictionary: 3772
# Length of dictionary after pruning: 3772
# Length of new dictionary: 5658
# Length of Original dictionary: 5658
# Length of dictionary after pruning: 5658
# Length of new dictionary: 8487
# Length of Original dictionary: 8487
# Length of dictionary after pruning: 8487
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 3561/3561
# P@1: 0.30131985397360295
# P@5: 0.5700645885987082
# P@10: 0.6517832069643359
#
#
# MRR: 0.42143191644397643
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (12.44s)
# 	- Objective:          56.5167%
# 	- Drop probability:   90.0000%
# ITERATION 20 (12.54s)
# 	- Objective:          57.3483%
# 	- Drop probability:   90.0000%
# ITERATION 30 (12.61s)
# 	- Objective:          57.5867%
# 	- Drop probability:   90.0000%
# ITERATION 40 (12.72s)
# 	- Objective:          57.8018%
# 	- Drop probability:   90.0000%
# ITERATION 50 (12.86s)
# 	- Objective:          58.1226%
# 	- Drop probability:   90.0000%
# ITERATION 60 (13.02s)
# 	- Objective:          58.1959%
# 	- Drop probability:   90.0000%
# ITERATION 70 (13.25s)
# 	- Objective:          58.2817%
# 	- Drop probability:   90.0000%
# ITERATION 80 (13.54s)
# 	- Objective:          58.3406%
# 	- Drop probability:   90.0000%
# ITERATION 90 (13.80s)
# 	- Objective:          58.7198%
# 	- Drop probability:   90.0000%
# ITERATION 100 (13.66s)
# 	- Objective:          58.8746%
# 	- Drop probability:   90.0000%
# ITERATION 110 (13.52s)
# 	- Objective:          58.8950%
# 	- Drop probability:   90.0000%
# ITERATION 120 (13.43s)
# 	- Objective:          58.8548%
# 	- Drop probability:   90.0000%
# ITERATION 130 (13.40s)
# 	- Objective:          58.8950%
# 	- Drop probability:   90.0000%
# ITERATION 140 (13.51s)
# 	- Objective:          58.8778%
# 	- Drop probability:   90.0000%
# ITERATION 150 (13.59s)
# 	- Objective:          58.9130%
# 	- Drop probability:   90.0000%
# ITERATION 160 (13.60s)
# 	- Objective:          58.8998%
# 	- Drop probability:   90.0000%
# ITERATION 170 (13.56s)
# 	- Objective:          58.8761%
# 	- Drop probability:   90.0000%
# ITERATION 180 (13.51s)
# 	- Objective:          58.8979%
# 	- Drop probability:   90.0000%
# ITERATION 190 (13.48s)
# 	- Objective:          58.8764%
# 	- Drop probability:   90.0000%
# ITERATION 200 (13.49s)
# 	- Objective:          58.8946%
# 	- Drop probability:   90.0000%
# ITERATION 210 (13.57s)
# 	- Objective:          59.3100%
# 	- Drop probability:   80.0000%
# ITERATION 220 (13.57s)
# 	- Objective:          59.3704%
# 	- Drop probability:   80.0000%
# ITERATION 230 (13.57s)
# 	- Objective:          59.3558%
# 	- Drop probability:   80.0000%
# ITERATION 240 (13.57s)
# 	- Objective:          59.3769%
# 	- Drop probability:   80.0000%
# ITERATION 250 (13.58s)
# 	- Objective:          59.4555%
# 	- Drop probability:   80.0000%
# ITERATION 260 (13.57s)
# 	- Objective:          59.4511%
# 	- Drop probability:   80.0000%
# ITERATION 270 (13.54s)
# 	- Objective:          59.4497%
# 	- Drop probability:   80.0000%
# ITERATION 280 (13.55s)
# 	- Objective:          59.4415%
# 	- Drop probability:   80.0000%
# ITERATION 290 (13.58s)
# 	- Objective:          59.4503%
# 	- Drop probability:   80.0000%
# ITERATION 300 (13.57s)
# 	- Objective:          59.4479%
# 	- Drop probability:   80.0000%
# ITERATION 310 (13.55s)
# 	- Objective:          59.7780%
# 	- Drop probability:   60.0000%
# ITERATION 320 (13.58s)
# 	- Objective:          59.7903%
# 	- Drop probability:   60.0000%
# ITERATION 330 (13.57s)
# 	- Objective:          59.7920%
# 	- Drop probability:   60.0000%
# ITERATION 340 (13.57s)
# 	- Objective:          59.7793%
# 	- Drop probability:   60.0000%
# ITERATION 350 (13.57s)
# 	- Objective:          59.7864%
# 	- Drop probability:   60.0000%
# ITERATION 360 (13.57s)
# 	- Objective:          59.7956%
# 	- Drop probability:   60.0000%
# ITERATION 370 (13.59s)
# 	- Objective:          59.7903%
# 	- Drop probability:   60.0000%
# ITERATION 380 (13.58s)
# 	- Objective:          59.7861%
# 	- Drop probability:   60.0000%
# ITERATION 390 (13.57s)
# 	- Objective:          60.0074%
# 	- Drop probability:   20.0000%
# ITERATION 400 (13.58s)
# 	- Objective:          60.0195%
# 	- Drop probability:   20.0000%
# ITERATION 410 (13.63s)
# 	- Objective:          60.0189%
# 	- Drop probability:   20.0000%
# ITERATION 420 (13.62s)
# 	- Objective:          60.0236%
# 	- Drop probability:   20.0000%
# ITERATION 430 (13.59s)
# 	- Objective:          60.0224%
# 	- Drop probability:   20.0000%
# ITERATION 440 (13.58s)
# 	- Objective:          60.0216%
# 	- Drop probability:   20.0000%
# ITERATION 450 (13.58s)
# 	- Objective:          60.0242%
# 	- Drop probability:   20.0000%
# ITERATION 460 (13.59s)
# 	- Objective:          60.0226%
# 	- Drop probability:   20.0000%
# ITERATION 470 (13.59s)
# 	- Objective:          60.0216%
# 	- Drop probability:   20.0000%
# ITERATION 480 (13.09s)
# 	- Objective:          60.0744%
# 	- Drop probability:    0.0000%
# ITERATION 490 (12.35s)
# 	- Objective:          60.0742%
# 	- Drop probability:    0.0000%
# ITERATION 500 (12.35s)
# 	- Objective:          60.0742%
# 	- Drop probability:    0.0000%
# ITERATION 510 (12.36s)
# 	- Objective:          60.0742%
# 	- Drop probability:    0.0000%
# ITERATION 520 (12.36s)
# 	- Objective:          60.0742%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 3561/3561
# P@1: 0.29795001404099974
# P@5: 0.5678180286436394
# P@10: 0.6486941870261163
#
#
# MRR: 0.41765144287134337
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=5069051.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=512.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1115590446.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, max=3561.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3561.0), HTML(value='')))
# Number of Test Translations: 3561/3561
# P@1: 0.20864925582701488
# P@5: 0.3066554338668913
# P@10: 0.32462791350744175
#
#
# MRR: 0.2525664188879662
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=3561.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3561.0), HTML(value='')))
# Number of Test Translations: 3561/3561
# P@1: 0.11822521763549565
# P@5: 0.14462229710755406
# P@10: 0.15782083684358325
#
#
# MRR: 0.13278305720414538

# %% [markdown]
# # 2. EN-POL

# %%
path_source_language = "../data/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "../data/monolingual_embedding/fasttext.wiki.pol.300.vocab.vec"
train_translation_dict_path = "../data/translation_dict/en-pl.0-5000.txt"
train_translation_dict_1k_path = "../data/translation_dict/en-pol.0-500.txt"
test_translation_dict_path = "../data/translation_dict/en-pl.5000-6500.txt"

new_test_translation_path = "../data/translation_dict/yacle.test.freq.cutoff.en-pl.tsv"

clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                   train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                   "en_pl", number_tokens=100000,  save_embedding=False)
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 2745
# New Dictionary Size: 2584
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 12201
# Length of dictionary after pruning: 11821
#
#
# Number of Test Translations: 2584/2584
# P@1: 0.31656346749226005
# P@5: 0.641640866873065
# P@10: 0.7287151702786377
#
#
# MRR: 0.46062657598031814
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1497
# Length of dictionary after pruning: 1476
#
#
# Number of Test Translations: 2584/2584
# P@1: 0.16950464396284828
# P@5: 0.39009287925696595
# P@10: 0.4887770897832817
#
#
# MRR: 0.27367271935846665
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1497
# Length of Original dictionary: 1497
# Length of dictionary after pruning: 1476
# Length of new dictionary: 2245
# Length of Original dictionary: 2245
# Length of dictionary after pruning: 2245
# Length of new dictionary: 3367
# Length of Original dictionary: 3367
# Length of dictionary after pruning: 3367
# Length of new dictionary: 5050
# Length of Original dictionary: 5050
# Length of dictionary after pruning: 5050
# Length of new dictionary: 7575
# Length of Original dictionary: 7575
# Length of dictionary after pruning: 7575
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 2584/2584
# P@1: 0.3254643962848297
# P@5: 0.6130030959752322
# P@10: 0.7070433436532507
#
#
# MRR: 0.4544944232250025
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (26.73s)
# 	- Objective:          42.1367%
# 	- Drop probability:   90.0000%
# ITERATION 20 (25.14s)
# 	- Objective:          49.8127%
# 	- Drop probability:   90.0000%
# ITERATION 30 (25.26s)
# 	- Objective:          52.1765%
# 	- Drop probability:   90.0000%
# ITERATION 40 (25.38s)
# 	- Objective:          52.6318%
# 	- Drop probability:   90.0000%
# ITERATION 50 (25.40s)
# 	- Objective:          52.9039%
# 	- Drop probability:   90.0000%
# ITERATION 60 (25.44s)
# 	- Objective:          52.9889%
# 	- Drop probability:   90.0000%
# ITERATION 70 (25.44s)
# 	- Objective:          53.0178%
# 	- Drop probability:   90.0000%
# ITERATION 80 (25.42s)
# 	- Objective:          53.0127%
# 	- Drop probability:   90.0000%
# ITERATION 90 (25.43s)
# 	- Objective:          53.0135%
# 	- Drop probability:   90.0000%
# ITERATION 100 (25.45s)
# 	- Objective:          53.0196%
# 	- Drop probability:   90.0000%
# ITERATION 110 (25.41s)
# 	- Objective:          53.0373%
# 	- Drop probability:   90.0000%
# ITERATION 120 (25.42s)
# 	- Objective:          53.0100%
# 	- Drop probability:   90.0000%
# ITERATION 130 (25.43s)
# 	- Objective:          53.0257%
# 	- Drop probability:   90.0000%
# ITERATION 140 (25.43s)
# 	- Objective:          53.0212%
# 	- Drop probability:   90.0000%
# ITERATION 150 (25.40s)
# 	- Objective:          53.0085%
# 	- Drop probability:   90.0000%
# ITERATION 160 (25.42s)
# 	- Objective:          53.0184%
# 	- Drop probability:   90.0000%
# ITERATION 170 (25.38s)
# 	- Objective:          53.0225%
# 	- Drop probability:   90.0000%
# ITERATION 180 (25.42s)
# 	- Objective:          53.0063%
# 	- Drop probability:   90.0000%
# ITERATION 190 (25.41s)
# 	- Objective:          53.4530%
# 	- Drop probability:   80.0000%
# ITERATION 200 (25.41s)
# 	- Objective:          53.4818%
# 	- Drop probability:   80.0000%
# ITERATION 210 (25.43s)
# 	- Objective:          53.4709%
# 	- Drop probability:   80.0000%
# ITERATION 220 (25.44s)
# 	- Objective:          53.4688%
# 	- Drop probability:   80.0000%
# ITERATION 230 (25.44s)
# 	- Objective:          53.4605%
# 	- Drop probability:   80.0000%
# ITERATION 240 (25.45s)
# 	- Objective:          53.4782%
# 	- Drop probability:   80.0000%
# ITERATION 250 (25.43s)
# 	- Objective:          53.4898%
# 	- Drop probability:   80.0000%
# ITERATION 260 (25.43s)
# 	- Objective:          53.5043%
# 	- Drop probability:   80.0000%
# ITERATION 270 (25.43s)
# 	- Objective:          53.5112%
# 	- Drop probability:   80.0000%
# ITERATION 280 (25.42s)
# 	- Objective:          53.5391%
# 	- Drop probability:   80.0000%
# ITERATION 290 (25.44s)
# 	- Objective:          53.5255%
# 	- Drop probability:   80.0000%
# ITERATION 300 (25.46s)
# 	- Objective:          53.5240%
# 	- Drop probability:   80.0000%
# ITERATION 310 (25.45s)
# 	- Objective:          53.5309%
# 	- Drop probability:   80.0000%
# ITERATION 320 (25.43s)
# 	- Objective:          53.5320%
# 	- Drop probability:   80.0000%
# ITERATION 330 (25.42s)
# 	- Objective:          53.5449%
# 	- Drop probability:   80.0000%
# ITERATION 340 (25.44s)
# 	- Objective:          53.5405%
# 	- Drop probability:   80.0000%
# ITERATION 350 (25.46s)
# 	- Objective:          53.5153%
# 	- Drop probability:   80.0000%
# ITERATION 360 (25.44s)
# 	- Objective:          53.5372%
# 	- Drop probability:   80.0000%
# ITERATION 370 (25.47s)
# 	- Objective:          53.5338%
# 	- Drop probability:   80.0000%
# ITERATION 380 (25.47s)
# 	- Objective:          53.5280%
# 	- Drop probability:   80.0000%
# ITERATION 390 (25.46s)
# 	- Objective:          53.5310%
# 	- Drop probability:   60.0000%
# ITERATION 400 (25.46s)
# 	- Objective:          53.9290%
# 	- Drop probability:   60.0000%
# ITERATION 410 (25.45s)
# 	- Objective:          53.9984%
# 	- Drop probability:   60.0000%
# ITERATION 420 (25.45s)
# 	- Objective:          54.0262%
# 	- Drop probability:   60.0000%
# ITERATION 430 (25.47s)
# 	- Objective:          54.0241%
# 	- Drop probability:   60.0000%
# ITERATION 440 (25.47s)
# 	- Objective:          54.0260%
# 	- Drop probability:   60.0000%
# ITERATION 450 (25.45s)
# 	- Objective:          54.0257%
# 	- Drop probability:   60.0000%
# ITERATION 460 (25.47s)
# 	- Objective:          54.0295%
# 	- Drop probability:   60.0000%
# ITERATION 470 (25.46s)
# 	- Objective:          54.0360%
# 	- Drop probability:   60.0000%
# ITERATION 480 (25.45s)
# 	- Objective:          54.0258%
# 	- Drop probability:   60.0000%
# ITERATION 490 (25.47s)
# 	- Objective:          54.0288%
# 	- Drop probability:   60.0000%
# ITERATION 500 (25.46s)
# 	- Objective:          54.0333%
# 	- Drop probability:   60.0000%
# ITERATION 510 (25.43s)
# 	- Objective:          54.0268%
# 	- Drop probability:   60.0000%
# ITERATION 520 (25.43s)
# 	- Objective:          54.0320%
# 	- Drop probability:   60.0000%
# ITERATION 530 (25.44s)
# 	- Objective:          54.0292%
# 	- Drop probability:   60.0000%
# ITERATION 540 (25.46s)
# 	- Objective:          54.0362%
# 	- Drop probability:   60.0000%
# ITERATION 550 (25.47s)
# 	- Objective:          54.2911%
# 	- Drop probability:   20.0000%
# ITERATION 560 (25.45s)
# 	- Objective:          54.2985%
# 	- Drop probability:   20.0000%
# ITERATION 570 (25.44s)
# 	- Objective:          54.2977%
# 	- Drop probability:   20.0000%
# ITERATION 580 (25.43s)
# 	- Objective:          54.2952%
# 	- Drop probability:   20.0000%
# ITERATION 590 (25.43s)
# 	- Objective:          54.2991%
# 	- Drop probability:   20.0000%
# ITERATION 600 (25.46s)
# 	- Objective:          54.2964%
# 	- Drop probability:   20.0000%
# ITERATION 610 (25.45s)
# 	- Objective:          54.2933%
# 	- Drop probability:   20.0000%
# ITERATION 620 (25.46s)
# 	- Objective:          54.2918%
# 	- Drop probability:   20.0000%
# ITERATION 630 (25.47s)
# 	- Objective:          54.2939%
# 	- Drop probability:   20.0000%
# ITERATION 640 (25.48s)
# 	- Objective:          54.2956%
# 	- Drop probability:   20.0000%
# ITERATION 650 (25.47s)
# 	- Objective:          54.2910%
# 	- Drop probability:   20.0000%
# ITERATION 660 (24.78s)
# 	- Objective:          54.3544%
# 	- Drop probability:    0.0000%
# ITERATION 670 (23.17s)
# 	- Objective:          54.3551%
# 	- Drop probability:    0.0000%
# ITERATION 680 (23.12s)
# 	- Objective:          54.3551%
# 	- Drop probability:    0.0000%
# ITERATION 690 (23.19s)
# 	- Objective:          54.3551%
# 	- Drop probability:    0.0000%
# ITERATION 700 (23.16s)
# 	- Objective:          54.3551%
# 	- Drop probability:    0.0000%
# ITERATION 710 (23.21s)
# 	- Objective:          54.3551%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 2584/2584
# P@1: 0.3045665634674923
# P@5: 0.5948142414860681
# P@10: 0.6907894736842105
#
#
# MRR: 0.43543515724820075
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=5069051.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=512.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1115590446.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, max=2584.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2584.0), HTML(value='')))
# Number of Test Translations: 2584/2584
# P@1: 0.23258513931888544
# P@5: 0.30688854489164086
# P@10: 0.3173374613003096
#
#
# MRR: 0.26757572093042115
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=2584.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2584.0), HTML(value='')))
# Number of Test Translations: 2584/2584
# P@1: 0.13660990712074303
# P@5: 0.16215170278637772
# P@10: 0.17879256965944273
#
#
# MRR: 0.1516095785544099

# %% [markdown]
# # 3. EN-NL

# %%
path_source_language = "../data/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "../data/monolingual_embedding/wiki.nl.vec"
train_translation_dict_path = "../data/translation_dict/en-nl.0-5000.txt"
train_translation_dict_1k_path = "../data/translation_dict/en-nl.0-500.txt"
test_translation_dict_path = "../data/translation_dict/en-nl.5000-6500.txt"

new_test_translation_path = "../data/translation_dict/yacle.test.freq.cutoff.en-nl.tsv"

clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                "en_nl", number_tokens=100000)
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 2481
# New Dictionary Size: 2412
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 9419
# Length of dictionary after pruning: 9237
#
#
# Number of Test Translations: 2412/2412
# P@1: 0.41376451077943616
# P@5: 0.6695688225538972
# P@10: 0.7458540630182421
#
#
# MRR: 0.5335588512957985
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1021
# Length of dictionary after pruning: 1012
#
#
# Number of Test Translations: 2412/2412
# P@1: 0.24543946932006633
# P@5: 0.4792703150912106
# P@10: 0.5522388059701493
#
#
# MRR: 0.3531230253992282
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1021
# Length of Original dictionary: 1021
# Length of dictionary after pruning: 1012
# Length of new dictionary: 1531
# Length of Original dictionary: 1531
# Length of dictionary after pruning: 1531
# Length of new dictionary: 2296
# Length of Original dictionary: 2296
# Length of dictionary after pruning: 2296
# Length of new dictionary: 3444
# Length of Original dictionary: 3444
# Length of dictionary after pruning: 3444
# Length of new dictionary: 5166
# Length of Original dictionary: 5166
# Length of dictionary after pruning: 5166
# Length of new dictionary: 7749
# Length of Original dictionary: 7749
# Length of dictionary after pruning: 7749
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 2412/2412
# P@1: 0.42330016583747926
# P@5: 0.677860696517413
# P@10: 0.7425373134328358
#
#
# MRR: 0.5390970244842055
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (12.68s)
# 	- Objective:          54.0417%
# 	- Drop probability:   90.0000%
# ITERATION 20 (12.53s)
# 	- Objective:          55.4287%
# 	- Drop probability:   90.0000%
# ITERATION 30 (12.58s)
# 	- Objective:          55.4581%
# 	- Drop probability:   90.0000%
# ITERATION 40 (12.68s)
# 	- Objective:          55.4526%
# 	- Drop probability:   90.0000%
# ITERATION 50 (12.76s)
# 	- Objective:          55.4616%
# 	- Drop probability:   90.0000%
# ITERATION 60 (12.91s)
# 	- Objective:          55.4720%
# 	- Drop probability:   90.0000%
# ITERATION 70 (13.05s)
# 	- Objective:          55.4762%
# 	- Drop probability:   90.0000%
# ITERATION 80 (13.27s)
# 	- Objective:          55.4871%
# 	- Drop probability:   90.0000%
# ITERATION 90 (13.59s)
# 	- Objective:          55.4829%
# 	- Drop probability:   90.0000%
# ITERATION 100 (13.82s)
# 	- Objective:          55.4898%
# 	- Drop probability:   90.0000%
# ITERATION 110 (13.63s)
# 	- Objective:          55.4882%
# 	- Drop probability:   90.0000%
# ITERATION 120 (13.45s)
# 	- Objective:          55.4748%
# 	- Drop probability:   90.0000%
# ITERATION 130 (13.39s)
# 	- Objective:          55.4570%
# 	- Drop probability:   90.0000%
# ITERATION 140 (13.40s)
# 	- Objective:          55.9371%
# 	- Drop probability:   80.0000%
# ITERATION 150 (13.46s)
# 	- Objective:          56.5978%
# 	- Drop probability:   80.0000%
# ITERATION 160 (13.54s)
# 	- Objective:          56.7418%
# 	- Drop probability:   80.0000%
# ITERATION 170 (13.59s)
# 	- Objective:          56.7709%
# 	- Drop probability:   80.0000%
# ITERATION 180 (13.56s)
# 	- Objective:          56.7664%
# 	- Drop probability:   80.0000%
# ITERATION 190 (13.50s)
# 	- Objective:          56.7673%
# 	- Drop probability:   80.0000%
# ITERATION 200 (13.51s)
# 	- Objective:          56.7702%
# 	- Drop probability:   80.0000%
# ITERATION 210 (13.49s)
# 	- Objective:          56.7474%
# 	- Drop probability:   80.0000%
# ITERATION 220 (13.47s)
# 	- Objective:          56.7603%
# 	- Drop probability:   80.0000%
# ITERATION 230 (13.50s)
# 	- Objective:          56.7559%
# 	- Drop probability:   80.0000%
# ITERATION 240 (13.48s)
# 	- Objective:          56.7486%
# 	- Drop probability:   80.0000%
# ITERATION 250 (13.47s)
# 	- Objective:          57.0778%
# 	- Drop probability:   60.0000%
# ITERATION 260 (13.55s)
# 	- Objective:          57.1002%
# 	- Drop probability:   60.0000%
# ITERATION 270 (13.58s)
# 	- Objective:          57.1130%
# 	- Drop probability:   60.0000%
# ITERATION 280 (13.58s)
# 	- Objective:          57.1106%
# 	- Drop probability:   60.0000%
# ITERATION 290 (13.58s)
# 	- Objective:          57.1249%
# 	- Drop probability:   60.0000%
# ITERATION 300 (13.55s)
# 	- Objective:          57.1412%
# 	- Drop probability:   60.0000%
# ITERATION 310 (13.55s)
# 	- Objective:          57.1426%
# 	- Drop probability:   60.0000%
# ITERATION 320 (13.56s)
# 	- Objective:          57.1408%
# 	- Drop probability:   60.0000%
# ITERATION 330 (13.53s)
# 	- Objective:          57.1440%
# 	- Drop probability:   60.0000%
# ITERATION 340 (13.49s)
# 	- Objective:          57.1568%
# 	- Drop probability:   60.0000%
# ITERATION 350 (13.52s)
# 	- Objective:          57.1525%
# 	- Drop probability:   60.0000%
# ITERATION 360 (13.51s)
# 	- Objective:          57.1569%
# 	- Drop probability:   60.0000%
# ITERATION 370 (13.47s)
# 	- Objective:          57.2003%
# 	- Drop probability:   60.0000%
# ITERATION 380 (13.50s)
# 	- Objective:          57.2167%
# 	- Drop probability:   60.0000%
# ITERATION 390 (13.56s)
# 	- Objective:          57.2175%
# 	- Drop probability:   60.0000%
# ITERATION 400 (13.56s)
# 	- Objective:          57.2182%
# 	- Drop probability:   60.0000%
# ITERATION 410 (13.54s)
# 	- Objective:          57.2103%
# 	- Drop probability:   60.0000%
# ITERATION 420 (13.51s)
# 	- Objective:          57.2124%
# 	- Drop probability:   60.0000%
# ITERATION 430 (13.50s)
# 	- Objective:          57.2117%
# 	- Drop probability:   60.0000%
# ITERATION 440 (13.53s)
# 	- Objective:          57.4765%
# 	- Drop probability:   20.0000%
# ITERATION 450 (13.58s)
# 	- Objective:          57.4948%
# 	- Drop probability:   20.0000%
# ITERATION 460 (13.53s)
# 	- Objective:          57.4974%
# 	- Drop probability:   20.0000%
# ITERATION 470 (13.54s)
# 	- Objective:          57.4964%
# 	- Drop probability:   20.0000%
# ITERATION 480 (13.58s)
# 	- Objective:          57.4976%
# 	- Drop probability:   20.0000%
# ITERATION 490 (13.55s)
# 	- Objective:          57.4971%
# 	- Drop probability:   20.0000%
# ITERATION 500 (13.57s)
# 	- Objective:          57.4974%
# 	- Drop probability:   20.0000%
# ITERATION 510 (13.56s)
# 	- Objective:          57.4977%
# 	- Drop probability:   20.0000%
# ITERATION 520 (13.57s)
# 	- Objective:          57.5031%
# 	- Drop probability:   20.0000%
# ITERATION 530 (13.57s)
# 	- Objective:          57.5029%
# 	- Drop probability:   20.0000%
# ITERATION 540 (13.53s)
# 	- Objective:          57.5033%
# 	- Drop probability:   20.0000%
# ITERATION 550 (13.55s)
# 	- Objective:          57.5019%
# 	- Drop probability:   20.0000%
# ITERATION 560 (13.57s)
# 	- Objective:          57.4991%
# 	- Drop probability:   20.0000%
# ITERATION 570 (13.52s)
# 	- Objective:          57.5054%
# 	- Drop probability:   20.0000%
# ITERATION 580 (13.53s)
# 	- Objective:          57.5085%
# 	- Drop probability:   20.0000%
# ITERATION 590 (13.57s)
# 	- Objective:          57.5023%
# 	- Drop probability:   20.0000%
# ITERATION 600 (13.56s)
# 	- Objective:          57.5056%
# 	- Drop probability:   20.0000%
# ITERATION 610 (13.56s)
# 	- Objective:          57.5101%
# 	- Drop probability:   20.0000%
# ITERATION 620 (13.55s)
# 	- Objective:          57.5067%
# 	- Drop probability:   20.0000%
# ITERATION 630 (13.58s)
# 	- Objective:          57.5080%
# 	- Drop probability:   20.0000%
# ITERATION 640 (13.59s)
# 	- Objective:          57.5169%
# 	- Drop probability:   20.0000%
# ITERATION 650 (13.58s)
# 	- Objective:          57.5176%
# 	- Drop probability:   20.0000%
# ITERATION 660 (13.58s)
# 	- Objective:          57.5124%
# 	- Drop probability:   20.0000%
# ITERATION 670 (13.56s)
# 	- Objective:          57.5116%
# 	- Drop probability:   20.0000%
# ITERATION 680 (13.54s)
# 	- Objective:          57.5080%
# 	- Drop probability:   20.0000%
# ITERATION 690 (13.59s)
# 	- Objective:          57.5262%
# 	- Drop probability:   20.0000%
# ITERATION 700 (13.55s)
# 	- Objective:          57.5316%
# 	- Drop probability:   20.0000%
# ITERATION 710 (13.56s)
# 	- Objective:          57.5404%
# 	- Drop probability:   20.0000%
# ITERATION 720 (13.55s)
# 	- Objective:          57.5566%
# 	- Drop probability:   20.0000%
# ITERATION 730 (13.55s)
# 	- Objective:          57.5898%
# 	- Drop probability:   20.0000%
# ITERATION 740 (13.54s)
# 	- Objective:          57.5952%
# 	- Drop probability:   20.0000%
# ITERATION 750 (13.58s)
# 	- Objective:          57.5934%
# 	- Drop probability:   20.0000%
# ITERATION 760 (13.56s)
# 	- Objective:          57.5914%
# 	- Drop probability:   20.0000%
# ITERATION 770 (13.58s)
# 	- Objective:          57.5910%
# 	- Drop probability:   20.0000%
# ITERATION 780 (13.55s)
# 	- Objective:          57.5916%
# 	- Drop probability:   20.0000%
# ITERATION 790 (13.54s)
# 	- Objective:          57.5974%
# 	- Drop probability:   20.0000%
# ITERATION 800 (13.56s)
# 	- Objective:          57.5960%
# 	- Drop probability:   20.0000%
# ITERATION 810 (13.57s)
# 	- Objective:          57.5953%
# 	- Drop probability:   20.0000%
# ITERATION 820 (13.58s)
# 	- Objective:          57.5958%
# 	- Drop probability:   20.0000%
# ITERATION 830 (13.53s)
# 	- Objective:          57.6003%
# 	- Drop probability:   20.0000%
# ITERATION 840 (13.50s)
# 	- Objective:          57.6008%
# 	- Drop probability:   20.0000%
# ITERATION 850 (13.57s)
# 	- Objective:          57.5961%
# 	- Drop probability:   20.0000%
# ITERATION 860 (13.57s)
# 	- Objective:          57.5985%
# 	- Drop probability:   20.0000%
# ITERATION 870 (13.57s)
# 	- Objective:          57.5974%
# 	- Drop probability:   20.0000%
# ITERATION 880 (13.58s)
# 	- Objective:          57.5942%
# 	- Drop probability:   20.0000%
# ITERATION 890 (12.71s)
# 	- Objective:          57.6587%
# 	- Drop probability:    0.0000%
# ITERATION 900 (12.32s)
# 	- Objective:          57.6588%
# 	- Drop probability:    0.0000%
# ITERATION 910 (12.29s)
# 	- Objective:          57.6588%
# 	- Drop probability:    0.0000%
# ITERATION 920 (12.33s)
# 	- Objective:          57.6588%
# 	- Drop probability:    0.0000%
# ITERATION 930 (12.35s)
# 	- Objective:          57.6588%
# 	- Drop probability:    0.0000%
# ITERATION 940 (12.38s)
# 	- Objective:          57.6588%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 2412/2412
# P@1: 0.4224709784411277
# P@5: 0.6683250414593698
# P@10: 0.7350746268656716
#
#
# MRR: 0.5345995726618554
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, max=2412.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2412.0), HTML(value='')))
# Number of Test Translations: 2412/2412
# P@1: 0.32587064676616917
# P@5: 0.4033996683250415
# P@10: 0.41832504145936983
#
#
# MRR: 0.36270461225684275
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=2412.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2412.0), HTML(value='')))
# Number of Test Translations: 2412/2412
# P@1: 0.19112769485903813
# P@5: 0.22470978441127695
# P@10: 0.2433665008291874
#
#
# MRR: 0.20965476294460786

# %% [markdown]
# # 4. EN-FI

# %%
path_source_language = "../data/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "../data/monolingual_embedding/fasttext.wiki.fi.300.vocab_200K.vec"
train_translation_dict_path = "../data/translation_dict/en-fi.0-5000.txt"
train_translation_dict_1k_path = "../data/translation_dict/en-fi.0-500.txt"
test_translation_dict_path = "../data/translation_dict/en-fi.5000-6500.txt"

new_test_translation_path = "/content/drive/MyDrive/CLIR/translation_dict/yacle.test.freq.cutoff.en-fi.tsv"

clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                "en_fi", number_tokens=100000)
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 2517
# New Dictionary Size: 2349
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 11496
# Length of dictionary after pruning: 11070
#
#
# Number of Test Translations: 2349/2349
# P@1: 0.2707535121328225
# P@5: 0.5615155385270327
# P@10: 0.6577266922094508
#
#
# MRR: 0.40308053342830696
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1412
# Length of dictionary after pruning: 1390
#
#
# Number of Test Translations: 2349/2349
# P@1: 0.12175393784589186
# P@5: 0.31375053214133675
# P@10: 0.40272456364410386
#
#
# MRR: 0.2156435105812954
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1412
# Length of Original dictionary: 1412
# Length of dictionary after pruning: 1390
# Length of new dictionary: 2118
# Length of Original dictionary: 2118
# Length of dictionary after pruning: 2118
# Length of new dictionary: 3177
# Length of Original dictionary: 3177
# Length of dictionary after pruning: 3177
# Length of new dictionary: 4765
# Length of Original dictionary: 4765
# Length of dictionary after pruning: 4765
# Length of new dictionary: 7147
# Length of Original dictionary: 7147
# Length of dictionary after pruning: 7147
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 2349/2349
# P@1: 0.2558535547041294
# P@5: 0.5559812686249468
# P@10: 0.6402724563644104
#
#
# MRR: 0.38889336093738686
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (13.58s)
# 	- Objective:          40.9842%
# 	- Drop probability:   90.0000%
# ITERATION 20 (13.90s)
# 	- Objective:          42.6010%
# 	- Drop probability:   90.0000%
# ITERATION 30 (13.71s)
# 	- Objective:          46.8649%
# 	- Drop probability:   90.0000%
# ITERATION 40 (13.43s)
# 	- Objective:          50.0742%
# 	- Drop probability:   90.0000%
# ITERATION 50 (13.35s)
# 	- Objective:          50.5764%
# 	- Drop probability:   90.0000%
# ITERATION 60 (13.36s)
# 	- Objective:          50.7046%
# 	- Drop probability:   90.0000%
# ITERATION 70 (13.45s)
# 	- Objective:          50.6958%
# 	- Drop probability:   90.0000%
# ITERATION 80 (13.55s)
# 	- Objective:          50.6976%
# 	- Drop probability:   90.0000%
# ITERATION 90 (13.53s)
# 	- Objective:          50.7167%
# 	- Drop probability:   90.0000%
# ITERATION 100 (13.49s)
# 	- Objective:          50.7066%
# 	- Drop probability:   90.0000%
# ITERATION 110 (13.47s)
# 	- Objective:          50.7168%
# 	- Drop probability:   90.0000%
# ITERATION 120 (13.45s)
# 	- Objective:          50.7225%
# 	- Drop probability:   90.0000%
# ITERATION 130 (13.42s)
# 	- Objective:          50.7237%
# 	- Drop probability:   90.0000%
# ITERATION 140 (13.44s)
# 	- Objective:          50.7206%
# 	- Drop probability:   90.0000%
# ITERATION 150 (13.45s)
# 	- Objective:          50.7173%
# 	- Drop probability:   90.0000%
# ITERATION 160 (13.48s)
# 	- Objective:          50.7128%
# 	- Drop probability:   90.0000%
# ITERATION 170 (13.47s)
# 	- Objective:          50.7012%
# 	- Drop probability:   90.0000%
# ITERATION 180 (13.50s)
# 	- Objective:          50.7211%
# 	- Drop probability:   90.0000%
# ITERATION 190 (13.47s)
# 	- Objective:          51.1082%
# 	- Drop probability:   80.0000%
# ITERATION 200 (13.48s)
# 	- Objective:          51.1462%
# 	- Drop probability:   80.0000%
# ITERATION 210 (13.48s)
# 	- Objective:          51.2238%
# 	- Drop probability:   80.0000%
# ITERATION 220 (13.48s)
# 	- Objective:          51.2532%
# 	- Drop probability:   80.0000%
# ITERATION 230 (13.48s)
# 	- Objective:          51.2293%
# 	- Drop probability:   80.0000%
# ITERATION 240 (13.47s)
# 	- Objective:          51.2378%
# 	- Drop probability:   80.0000%
# ITERATION 250 (13.46s)
# 	- Objective:          51.2359%
# 	- Drop probability:   80.0000%
# ITERATION 260 (13.50s)
# 	- Objective:          51.2220%
# 	- Drop probability:   80.0000%
# ITERATION 270 (13.47s)
# 	- Objective:          51.2313%
# 	- Drop probability:   80.0000%
# ITERATION 280 (13.52s)
# 	- Objective:          51.5358%
# 	- Drop probability:   60.0000%
# ITERATION 290 (13.54s)
# 	- Objective:          51.5744%
# 	- Drop probability:   60.0000%
# ITERATION 300 (13.53s)
# 	- Objective:          51.5782%
# 	- Drop probability:   60.0000%
# ITERATION 310 (13.51s)
# 	- Objective:          51.5654%
# 	- Drop probability:   60.0000%
# ITERATION 320 (13.51s)
# 	- Objective:          51.5803%
# 	- Drop probability:   60.0000%
# ITERATION 330 (13.48s)
# 	- Objective:          51.5958%
# 	- Drop probability:   60.0000%
# ITERATION 340 (13.49s)
# 	- Objective:          51.5951%
# 	- Drop probability:   60.0000%
# ITERATION 350 (13.51s)
# 	- Objective:          51.6041%
# 	- Drop probability:   60.0000%
# ITERATION 360 (13.52s)
# 	- Objective:          51.6017%
# 	- Drop probability:   60.0000%
# ITERATION 370 (13.52s)
# 	- Objective:          51.6077%
# 	- Drop probability:   60.0000%
# ITERATION 380 (13.52s)
# 	- Objective:          51.6055%
# 	- Drop probability:   60.0000%
# ITERATION 390 (13.55s)
# 	- Objective:          51.6052%
# 	- Drop probability:   60.0000%
# ITERATION 400 (13.53s)
# 	- Objective:          51.6129%
# 	- Drop probability:   60.0000%
# ITERATION 410 (13.47s)
# 	- Objective:          51.6003%
# 	- Drop probability:   60.0000%
# ITERATION 420 (13.49s)
# 	- Objective:          51.6087%
# 	- Drop probability:   60.0000%
# ITERATION 430 (13.53s)
# 	- Objective:          51.9008%
# 	- Drop probability:   20.0000%
# ITERATION 440 (13.57s)
# 	- Objective:          52.3319%
# 	- Drop probability:   20.0000%
# ITERATION 450 (13.60s)
# 	- Objective:          52.3498%
# 	- Drop probability:   20.0000%
# ITERATION 460 (13.55s)
# 	- Objective:          52.3536%
# 	- Drop probability:   20.0000%
# ITERATION 470 (13.55s)
# 	- Objective:          52.3549%
# 	- Drop probability:   20.0000%
# ITERATION 480 (13.57s)
# 	- Objective:          52.3644%
# 	- Drop probability:   20.0000%
# ITERATION 490 (13.56s)
# 	- Objective:          52.3573%
# 	- Drop probability:   20.0000%
# ITERATION 500 (13.60s)
# 	- Objective:          52.3550%
# 	- Drop probability:   20.0000%
# ITERATION 510 (13.52s)
# 	- Objective:          52.3619%
# 	- Drop probability:   20.0000%
# ITERATION 520 (13.56s)
# 	- Objective:          52.3610%
# 	- Drop probability:   20.0000%
# ITERATION 530 (13.55s)
# 	- Objective:          52.3638%
# 	- Drop probability:   20.0000%
# ITERATION 540 (13.57s)
# 	- Objective:          52.3517%
# 	- Drop probability:   20.0000%
# ITERATION 550 (13.53s)
# 	- Objective:          52.3589%
# 	- Drop probability:   20.0000%
# ITERATION 560 (13.52s)
# 	- Objective:          52.3559%
# 	- Drop probability:   20.0000%
# ITERATION 570 (12.90s)
# 	- Objective:          52.4170%
# 	- Drop probability:    0.0000%
# ITERATION 580 (12.34s)
# 	- Objective:          52.4168%
# 	- Drop probability:    0.0000%
# ITERATION 590 (12.34s)
# 	- Objective:          52.4168%
# 	- Drop probability:    0.0000%
# ITERATION 600 (12.34s)
# 	- Objective:          52.4168%
# 	- Drop probability:    0.0000%
# ITERATION 610 (12.37s)
# 	- Objective:          52.4168%
# 	- Drop probability:    0.0000%
# ITERATION 620 (12.33s)
# 	- Objective:          52.4168%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 2349/2349
# P@1: 0.25372498935717325
# P@5: 0.5346956151553852
# P@10: 0.6360153256704981
#
#
# MRR: 0.38210024859117525
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, max=2349.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2349.0), HTML(value='')))
# Number of Test Translations: 2349/2349
# P@1: 0.2175393784589187
# P@5: 0.2601106853980417
# P@10: 0.2673478075776926
#
#
# MRR: 0.23927964727677578
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=2349.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2349.0), HTML(value='')))
# Number of Test Translations: 2349/2349
# P@1: 0.1502767134951043
# P@5: 0.1728395061728395
# P@10: 0.1839080459770115
#
#
# MRR: 0.16425003922541054

# %% [markdown]
# # 5. EN-RU

# %%
path_source_language = "/content/drive/MyDrive/CLIR/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "/content/drive/MyDrive/CLIR/monolingual_embedding/fasttext.wiki.ru.300.vocab_200K.vec"
train_translation_dict_path = "/content/drive/MyDrive/CLIR/translation_dict/en-ru.0-5000.txt"
train_translation_dict_1k_path = "/content/drive/MyDrive/CLIR/translation_dict/en-ru.0-500.txt"
test_translation_dict_path = "/content/drive/MyDrive/CLIR/translation_dict/en-ru.5000-6500.txt"

new_test_translation_path = "/content/drive/MyDrive/CLIR/translation_dict/yacle.test.freq.cutoff.en-ru.tsv"
try:
  clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                    train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                    "en_de", number_tokens=100000, save_embedding=False)
except:
  print("except")
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 2447
# New Dictionary Size: 2291
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 10887
# Length of dictionary after pruning: 10601
#
#
# Number of Test Translations: 2291/2291
# P@1: 0.31776516804888694
# P@5: 0.6302924487123527
# P@10: 0.7127891750327368
#
#
# MRR: 0.45576879639080314
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1376
# Length of dictionary after pruning: 1365
#
#
# Number of Test Translations: 2291/2291
# P@1: 0.18070711479703186
# P@5: 0.3950240069838499
# P@10: 0.4984722828459188
#
#
# MRR: 0.2837927396628475
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1376
# Length of Original dictionary: 1376
# Length of dictionary after pruning: 1365
# Length of new dictionary: 2064
# Length of Original dictionary: 2064
# Length of dictionary after pruning: 2064
# Length of new dictionary: 3096
# Length of Original dictionary: 3096
# Length of dictionary after pruning: 3096
# Length of new dictionary: 4644
# Length of Original dictionary: 4644
# Length of dictionary after pruning: 4644
# Length of new dictionary: 6966
# Length of Original dictionary: 6966
# Length of dictionary after pruning: 6966
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 2291/2291
# P@1: 0.2789175032736796
# P@5: 0.5835879528590135
# P@10: 0.6796158882584025
#
#
# MRR: 0.4152283135394629
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (13.97s)
# 	- Objective:          42.9672%
# 	- Drop probability:   90.0000%
# ITERATION 20 (13.86s)
# 	- Objective:          51.7204%
# 	- Drop probability:   90.0000%
# ITERATION 30 (13.51s)
# 	- Objective:          52.5708%
# 	- Drop probability:   90.0000%
# ITERATION 40 (13.33s)
# 	- Objective:          52.7678%
# 	- Drop probability:   90.0000%
# ITERATION 50 (13.25s)
# 	- Objective:          52.9964%
# 	- Drop probability:   90.0000%
# ITERATION 60 (13.35s)
# 	- Objective:          53.2237%
# 	- Drop probability:   90.0000%
# ITERATION 70 (13.43s)
# 	- Objective:          53.2609%
# 	- Drop probability:   90.0000%
# ITERATION 80 (13.54s)
# 	- Objective:          53.2560%
# 	- Drop probability:   90.0000%
# ITERATION 90 (13.52s)
# 	- Objective:          53.2646%
# 	- Drop probability:   90.0000%
# ITERATION 100 (13.43s)
# 	- Objective:          53.2738%
# 	- Drop probability:   90.0000%
# ITERATION 110 (13.38s)
# 	- Objective:          53.2718%
# 	- Drop probability:   90.0000%
# ITERATION 120 (13.38s)
# 	- Objective:          53.2739%
# 	- Drop probability:   90.0000%
# ITERATION 130 (13.39s)
# 	- Objective:          53.2781%
# 	- Drop probability:   90.0000%
# ITERATION 140 (13.44s)
# 	- Objective:          53.2633%
# 	- Drop probability:   90.0000%
# ITERATION 150 (13.45s)
# 	- Objective:          53.2754%
# 	- Drop probability:   90.0000%
# ITERATION 160 (13.45s)
# 	- Objective:          53.2726%
# 	- Drop probability:   90.0000%
# ITERATION 170 (13.43s)
# 	- Objective:          53.2976%
# 	- Drop probability:   90.0000%
# ITERATION 180 (13.44s)
# 	- Objective:          53.2958%
# 	- Drop probability:   90.0000%
# ITERATION 190 (13.43s)
# 	- Objective:          53.2612%
# 	- Drop probability:   90.0000%
# ITERATION 200 (13.39s)
# 	- Objective:          53.2818%
# 	- Drop probability:   90.0000%
# ITERATION 210 (13.42s)
# 	- Objective:          53.2926%
# 	- Drop probability:   90.0000%
# ITERATION 220 (13.42s)
# 	- Objective:          53.2738%
# 	- Drop probability:   90.0000%
# ITERATION 230 (13.41s)
# 	- Objective:          53.3013%
# 	- Drop probability:   80.0000%
# ITERATION 240 (13.45s)
# 	- Objective:          53.7000%
# 	- Drop probability:   80.0000%
# ITERATION 250 (13.42s)
# 	- Objective:          53.7230%
# 	- Drop probability:   80.0000%
# ITERATION 260 (13.44s)
# 	- Objective:          53.7421%
# 	- Drop probability:   80.0000%
# ITERATION 270 (13.45s)
# 	- Objective:          53.7832%
# 	- Drop probability:   80.0000%
# ITERATION 280 (13.44s)
# 	- Objective:          53.8972%
# 	- Drop probability:   80.0000%
# ITERATION 290 (13.41s)
# 	- Objective:          53.9299%
# 	- Drop probability:   80.0000%
# ITERATION 300 (13.39s)
# 	- Objective:          53.9730%
# 	- Drop probability:   80.0000%
# ITERATION 310 (13.41s)
# 	- Objective:          53.9793%
# 	- Drop probability:   80.0000%
# ITERATION 320 (13.44s)
# 	- Objective:          53.9788%
# 	- Drop probability:   80.0000%
# ITERATION 330 (13.39s)
# 	- Objective:          53.9637%
# 	- Drop probability:   80.0000%
# ITERATION 340 (13.42s)
# 	- Objective:          53.9735%
# 	- Drop probability:   80.0000%
# ITERATION 350 (13.45s)
# 	- Objective:          53.9777%
# 	- Drop probability:   80.0000%
# ITERATION 360 (13.43s)
# 	- Objective:          53.9737%
# 	- Drop probability:   80.0000%
# ITERATION 370 (13.42s)
# 	- Objective:          53.9886%
# 	- Drop probability:   80.0000%
# ITERATION 380 (13.45s)
# 	- Objective:          54.3285%
# 	- Drop probability:   60.0000%
# ITERATION 390 (13.46s)
# 	- Objective:          54.3363%
# 	- Drop probability:   60.0000%
# ITERATION 400 (13.45s)
# 	- Objective:          54.3527%
# 	- Drop probability:   60.0000%
# ITERATION 410 (13.44s)
# 	- Objective:          54.3612%
# 	- Drop probability:   60.0000%
# ITERATION 420 (13.41s)
# 	- Objective:          54.3694%
# 	- Drop probability:   60.0000%
# ITERATION 430 (13.42s)
# 	- Objective:          54.3619%
# 	- Drop probability:   60.0000%
# ITERATION 440 (13.49s)
# 	- Objective:          54.3647%
# 	- Drop probability:   60.0000%
# ITERATION 450 (13.53s)
# 	- Objective:          54.3621%
# 	- Drop probability:   60.0000%
# ITERATION 460 (13.48s)
# 	- Objective:          54.3671%
# 	- Drop probability:   60.0000%
# ITERATION 470 (13.44s)
# 	- Objective:          54.3669%
# 	- Drop probability:   60.0000%
# ITERATION 480 (13.41s)
# 	- Objective:          54.3566%
# 	- Drop probability:   60.0000%
# ITERATION 490 (13.40s)
# 	- Objective:          54.3644%
# 	- Drop probability:   60.0000%
# ITERATION 500 (13.43s)
# 	- Objective:          54.3755%
# 	- Drop probability:   60.0000%
# ITERATION 510 (13.40s)
# 	- Objective:          54.3790%
# 	- Drop probability:   60.0000%
# ITERATION 520 (13.46s)
# 	- Objective:          54.3711%
# 	- Drop probability:   60.0000%
# ITERATION 530 (13.46s)
# 	- Objective:          54.3825%
# 	- Drop probability:   60.0000%
# ITERATION 540 (13.45s)
# 	- Objective:          54.3922%
# 	- Drop probability:   60.0000%
# ITERATION 550 (13.45s)
# 	- Objective:          54.3929%
# 	- Drop probability:   60.0000%
# ITERATION 560 (13.41s)
# 	- Objective:          54.4186%
# 	- Drop probability:   60.0000%
# ITERATION 570 (13.44s)
# 	- Objective:          54.4126%
# 	- Drop probability:   60.0000%
# ITERATION 580 (13.41s)
# 	- Objective:          54.4272%
# 	- Drop probability:   60.0000%
# ITERATION 590 (13.47s)
# 	- Objective:          54.4279%
# 	- Drop probability:   60.0000%
# ITERATION 600 (13.44s)
# 	- Objective:          54.4203%
# 	- Drop probability:   60.0000%
# ITERATION 610 (13.44s)
# 	- Objective:          54.4311%
# 	- Drop probability:   60.0000%
# ITERATION 620 (13.46s)
# 	- Objective:          54.4264%
# 	- Drop probability:   60.0000%
# ITERATION 630 (13.44s)
# 	- Objective:          54.4221%
# 	- Drop probability:   60.0000%
# ITERATION 640 (13.44s)
# 	- Objective:          54.4200%
# 	- Drop probability:   60.0000%
# ITERATION 650 (13.44s)
# 	- Objective:          54.4353%
# 	- Drop probability:   60.0000%
# ITERATION 660 (13.42s)
# 	- Objective:          54.4248%
# 	- Drop probability:   60.0000%
# ITERATION 670 (13.44s)
# 	- Objective:          54.4305%
# 	- Drop probability:   60.0000%
# ITERATION 680 (13.44s)
# 	- Objective:          54.4241%
# 	- Drop probability:   60.0000%
# ITERATION 690 (13.47s)
# 	- Objective:          54.6806%
# 	- Drop probability:   20.0000%
# ITERATION 700 (13.46s)
# 	- Objective:          54.7066%
# 	- Drop probability:   20.0000%
# ITERATION 710 (13.44s)
# 	- Objective:          54.7707%
# 	- Drop probability:   20.0000%
# ITERATION 720 (13.50s)
# 	- Objective:          54.8094%
# 	- Drop probability:   20.0000%
# ITERATION 730 (13.49s)
# 	- Objective:          54.8476%
# 	- Drop probability:   20.0000%
# ITERATION 740 (13.45s)
# 	- Objective:          54.8575%
# 	- Drop probability:   20.0000%
# ITERATION 750 (13.48s)
# 	- Objective:          54.8631%
# 	- Drop probability:   20.0000%
# ITERATION 760 (13.45s)
# 	- Objective:          54.8567%
# 	- Drop probability:   20.0000%
# ITERATION 770 (13.48s)
# 	- Objective:          54.8637%
# 	- Drop probability:   20.0000%
# ITERATION 780 (13.46s)
# 	- Objective:          54.8590%
# 	- Drop probability:   20.0000%
# ITERATION 790 (13.45s)
# 	- Objective:          54.8636%
# 	- Drop probability:   20.0000%
# ITERATION 800 (13.46s)
# 	- Objective:          54.8561%
# 	- Drop probability:   20.0000%
# ITERATION 810 (13.47s)
# 	- Objective:          54.8655%
# 	- Drop probability:   20.0000%
# ITERATION 820 (13.46s)
# 	- Objective:          54.8587%
# 	- Drop probability:   20.0000%
# ITERATION 830 (13.47s)
# 	- Objective:          54.8596%
# 	- Drop probability:   20.0000%
# ITERATION 840 (13.46s)
# 	- Objective:          54.8619%
# 	- Drop probability:   20.0000%
# ITERATION 850 (13.48s)
# 	- Objective:          54.8572%
# 	- Drop probability:   20.0000%
# ITERATION 860 (13.48s)
# 	- Objective:          54.8607%
# 	- Drop probability:   20.0000%
# ITERATION 870 (12.66s)
# 	- Objective:          54.9174%
# 	- Drop probability:    0.0000%
# ITERATION 880 (12.32s)
# 	- Objective:          54.9174%
# 	- Drop probability:    0.0000%
# ITERATION 890 (12.31s)
# 	- Objective:          54.9174%
# 	- Drop probability:    0.0000%
# ITERATION 900 (12.27s)
# 	- Objective:          54.9174%
# 	- Drop probability:    0.0000%
# ITERATION 910 (12.29s)
# 	- Objective:          54.9174%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 2291/2291
# P@1: 0.27673505019642075
# P@5: 0.5896988214753383
# P@10: 0.6800523788738542
#
#
# MRR: 0.41696482370323523
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, max=2291.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2291.0), HTML(value='')))
# Number of Test Translations: 2291/2291
# P@1: 0.11305106940200786
# P@5: 0.21780881711043212
# P@10: 0.2409428197293758
#
#
# MRR: 0.16202785517892926
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=2291.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2291.0), HTML(value='')))
# Number of Test Translations: 2291/2291
# P@1: 0.02749890877346137
# P@5: 0.0405936272370144
# P@10: 0.04845045831514622
#
#
# MRR: 0.03619241105503459

# %% [markdown]
# # 6. EN-IT

# %%
path_source_language = "../data/monolingual_embedding/fasttext.wiki.en.300.vocab_200K.vec"
path_target_language = "../data/monolingual_embedding/wiki.it.vec"
train_translation_dict_path = "../data/translation_dict/en-it.0-5000.txt"
train_translation_dict_1k_path = "../data/translation_dict/en-it.0-500.txt"
test_translation_dict_path = "../data/translation_dict/en-it.5000-6500.txt"

new_test_translation_path = "../data/translation_dict/yacle.test.freq.cutoff.en-it.tsv"

clew_induction(path_source_language, path_target_language, train_translation_dict_path,
                train_translation_dict_1k_path, test_translation_dict_path, new_test_translation_path,
                "en_it", number_tokens=100000, save_embedding=False)
# Out:
# First, we cut the test dictionaries to the monolingual vocabularies:
# Original Dictionary Size: 2585
# New Dictionary Size: 2554
# --------------------------------
#
# Create procrustes model with 5000 translation pairs
# Length of Original dictionary: 9657
# Length of dictionary after pruning: 9575
#
#
# Number of Test Translations: 2554/2554
# P@1: 0.42521534847298353
# P@5: 0.6918559122944401
# P@10: 0.7599843382928739
#
#
# MRR: 0.5438951152149026
# --------------------------------
#
# Create procrustes model with 1000 translation pairs
# Length of Original dictionary: 1058
# Length of dictionary after pruning: 1056
#
#
# Number of Test Translations: 2554/2554
# P@1: 0.27721221613155833
# P@5: 0.5305403288958497
# P@10: 0.6049334377447142
#
#
# MRR: 0.39052255633687755
# --------------------------------
#
# Create procrustes bootstrapping model with 1000 translation pairs
# Length of Original dictionary: 1058
# Length of Original dictionary: 1058
# Length of dictionary after pruning: 1056
# Length of new dictionary: 1587
# Length of Original dictionary: 1587
# Length of dictionary after pruning: 1587
# Length of new dictionary: 2380
# Length of Original dictionary: 2380
# Length of dictionary after pruning: 2380
# Length of new dictionary: 3570
# Length of Original dictionary: 3570
# Length of dictionary after pruning: 3570
# Length of new dictionary: 5355
# Length of Original dictionary: 5355
# Length of dictionary after pruning: 5355
# Length of new dictionary: 8032
# Length of Original dictionary: 8032
# Length of dictionary after pruning: 8032
# Length of new dictionary: 10000
# Length of Original dictionary: 10000
# Length of dictionary after pruning: 10000
#
#
# Number of Test Translations: 2554/2554
# P@1: 0.437744714173845
# P@5: 0.6840250587314017
# P@10: 0.7517619420516837
#
#
# MRR: 0.54746921013507
# --------------------------------
#
# Create VecMap model
# ITERATION 10 (25.43s)
# 	- Objective:          57.1204%
# 	- Drop probability:   90.0000%
# ITERATION 20 (25.37s)
# 	- Objective:          57.7072%
# 	- Drop probability:   90.0000%
# ITERATION 30 (25.42s)
# 	- Objective:          57.9201%
# 	- Drop probability:   90.0000%
# ITERATION 40 (25.44s)
# 	- Objective:          57.9417%
# 	- Drop probability:   90.0000%
# ITERATION 50 (25.43s)
# 	- Objective:          57.9592%
# 	- Drop probability:   90.0000%
# ITERATION 60 (25.43s)
# 	- Objective:          57.9693%
# 	- Drop probability:   90.0000%
# ITERATION 70 (25.45s)
# 	- Objective:          57.9345%
# 	- Drop probability:   90.0000%
# ITERATION 80 (25.45s)
# 	- Objective:          57.9371%
# 	- Drop probability:   90.0000%
# ITERATION 90 (25.44s)
# 	- Objective:          57.9474%
# 	- Drop probability:   90.0000%
# ITERATION 100 (25.43s)
# 	- Objective:          58.3787%
# 	- Drop probability:   80.0000%
# ITERATION 110 (25.41s)
# 	- Objective:          58.3850%
# 	- Drop probability:   80.0000%
# ITERATION 120 (25.42s)
# 	- Objective:          58.3831%
# 	- Drop probability:   80.0000%
# ITERATION 130 (25.42s)
# 	- Objective:          58.3908%
# 	- Drop probability:   80.0000%
# ITERATION 140 (25.44s)
# 	- Objective:          58.4031%
# 	- Drop probability:   80.0000%
# ITERATION 150 (25.45s)
# 	- Objective:          58.4084%
# 	- Drop probability:   80.0000%
# ITERATION 160 (25.44s)
# 	- Objective:          58.3949%
# 	- Drop probability:   80.0000%
# ITERATION 170 (25.45s)
# 	- Objective:          58.3849%
# 	- Drop probability:   80.0000%
# ITERATION 180 (25.46s)
# 	- Objective:          58.4003%
# 	- Drop probability:   80.0000%
# ITERATION 190 (25.45s)
# 	- Objective:          58.3975%
# 	- Drop probability:   80.0000%
# ITERATION 200 (25.47s)
# 	- Objective:          58.4187%
# 	- Drop probability:   80.0000%
# ITERATION 210 (25.44s)
# 	- Objective:          58.4088%
# 	- Drop probability:   80.0000%
# ITERATION 220 (25.42s)
# 	- Objective:          58.4130%
# 	- Drop probability:   80.0000%
# ITERATION 230 (25.42s)
# 	- Objective:          58.4166%
# 	- Drop probability:   80.0000%
# ITERATION 240 (25.39s)
# 	- Objective:          58.4149%
# 	- Drop probability:   80.0000%
# ITERATION 250 (25.42s)
# 	- Objective:          58.4176%
# 	- Drop probability:   80.0000%
# ITERATION 260 (25.43s)
# 	- Objective:          58.4229%
# 	- Drop probability:   80.0000%
# ITERATION 270 (25.44s)
# 	- Objective:          58.4154%
# 	- Drop probability:   80.0000%
# ITERATION 280 (25.46s)
# 	- Objective:          58.4172%
# 	- Drop probability:   80.0000%
# ITERATION 290 (25.45s)
# 	- Objective:          58.4357%
# 	- Drop probability:   80.0000%
# ITERATION 300 (25.45s)
# 	- Objective:          58.4186%
# 	- Drop probability:   80.0000%
# ITERATION 310 (25.44s)
# 	- Objective:          58.4629%
# 	- Drop probability:   80.0000%
# ITERATION 320 (25.46s)
# 	- Objective:          58.4994%
# 	- Drop probability:   80.0000%
# ITERATION 330 (25.44s)
# 	- Objective:          58.5029%
# 	- Drop probability:   80.0000%
# ITERATION 340 (25.41s)
# 	- Objective:          58.4974%
# 	- Drop probability:   80.0000%
# ITERATION 350 (25.44s)
# 	- Objective:          58.4984%
# 	- Drop probability:   80.0000%
# ITERATION 360 (25.42s)
# 	- Objective:          58.4896%
# 	- Drop probability:   80.0000%
# ITERATION 370 (25.43s)
# 	- Objective:          58.4847%
# 	- Drop probability:   80.0000%
# ITERATION 380 (25.43s)
# 	- Objective:          58.8469%
# 	- Drop probability:   60.0000%
# ITERATION 390 (25.46s)
# 	- Objective:          58.8739%
# 	- Drop probability:   60.0000%
# ITERATION 400 (25.43s)
# 	- Objective:          58.9956%
# 	- Drop probability:   60.0000%
# ITERATION 410 (25.46s)
# 	- Objective:          59.0047%
# 	- Drop probability:   60.0000%
# ITERATION 420 (25.46s)
# 	- Objective:          59.0011%
# 	- Drop probability:   60.0000%
# ITERATION 430 (25.47s)
# 	- Objective:          59.0056%
# 	- Drop probability:   60.0000%
# ITERATION 440 (25.45s)
# 	- Objective:          59.0043%
# 	- Drop probability:   60.0000%
# ITERATION 450 (25.47s)
# 	- Objective:          58.9951%
# 	- Drop probability:   60.0000%
# ITERATION 460 (25.41s)
# 	- Objective:          59.0012%
# 	- Drop probability:   60.0000%
# ITERATION 470 (25.40s)
# 	- Objective:          59.2578%
# 	- Drop probability:   20.0000%
# ITERATION 480 (25.36s)
# 	- Objective:          59.2556%
# 	- Drop probability:   20.0000%
# ITERATION 490 (25.42s)
# 	- Objective:          59.2579%
# 	- Drop probability:   20.0000%
# ITERATION 500 (25.43s)
# 	- Objective:          59.2570%
# 	- Drop probability:   20.0000%
# ITERATION 510 (25.48s)
# 	- Objective:          59.2566%
# 	- Drop probability:   20.0000%
# ITERATION 520 (25.44s)
# 	- Objective:          59.2606%
# 	- Drop probability:   20.0000%
# ITERATION 530 (25.44s)
# 	- Objective:          59.2583%
# 	- Drop probability:   20.0000%
# ITERATION 540 (25.42s)
# 	- Objective:          59.2602%
# 	- Drop probability:   20.0000%
# ITERATION 550 (24.05s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
# ITERATION 560 (23.11s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
# ITERATION 570 (23.18s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
# ITERATION 580 (23.16s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
# ITERATION 590 (23.12s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
# ITERATION 600 (23.10s)
# 	- Objective:          59.3194%
# 	- Drop probability:    0.0000%
#
#
# Number of Test Translations: 2554/2554
# P@1: 0.4361785434612373
# P@5: 0.6801096319498825
# P@10: 0.7427564604541895
#
#
# MRR: 0.5461272453525438
# --------------------------------
#
# Create  Text Encoder First Layer model
# HBox(children=(FloatProgress(value=0.0, max=2554.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2554.0), HTML(value='')))
# Number of Test Translations: 2554/2554
# P@1: 0.31362568519968675
# P@5: 0.44675019577133906
# P@10: 0.4635865309318716
#
#
# MRR: 0.37417703255145207
# --------------------------------
#
# Create  Text Encoder Last Layer model
# HBox(children=(FloatProgress(value=0.0, max=2554.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2554.0), HTML(value='')))

# %% [markdown]
# # Create Subsets of dictionaries if needed here

# %%
import csv
from src.cross_lingual_embeddings.load_monolingual import load_translation_dict

path_dict = "../data/translation_dict/en-it.0-5000.txt"
save_path = "../data/translation_dict/en-it.0-500.txt"

translation_source, translation_target = load_translation_dict(path_dict)
text_file = ""
unique_words = set([])
for index, word in enumerate(translation_source):
    if len(unique_words) == 500:
        break
    text_file += translation_source[index] + " " + translation_target[index] + "\n"
    unique_words.add(word)

with open(save_path, 'w') as f:
    f.write(text_file)
