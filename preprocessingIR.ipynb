# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import StanfordTagger
from Data_Import import import_data
from Data_Cleansing import data_cleansing
from nltk.stem import WordNetLemmatizer
from HanTa import HanoverTagger as ht

# %% [markdown]
# #### Load data into Dataframe

# %%
# import data
df=import_data()

# %% [markdown]
# #### Data Cleansing: Tokenize by white spaces, lowercase, stopword removal

# %%
### get first 10.000 entries to test and get features
df_selected = df.sort_index().loc[0:10000]

# %%
pd.set_option('display.max_colwidth', 50)
df_selected
# Out:
#                                                  English  \
# 0                              Resumption of the session
# 1      I declare resumed the session of the European ...
# 2      Although, as you will have seen, the dreaded '...
# 3      You have requested a debate on this subject in...
# 4      In the meantime, I should like to observe a mi...
# ...                                                  ...
# 9996   For example, to accept new roads is to accept ...
# 9997   I would also ask the Commission to ensure that...
# 9998   I am particularly thinking in this respect of ...
# 9999   We know that some Member States are still wave...
# 10000  However, I am also thinking of my own region w...
#
#                                                   German
# 0                     Wiederaufnahme der Sitzungsperiode
# 1      Ich erkläre die am Freitag, dem 17. Dezember u...
# 2      Wie Sie feststellen konnten, ist der gefürchte...
# 3      Im Parlament besteht der Wunsch nach einer Aus...
# 4      Heute möchte ich Sie bitten - das ist auch der...
# ...                                                  ...
# 9996   Wenn man zum Beispiel neue Straßen akzeptiert,...
# 9997   Ich fordere auch, daß die Kommission bei der P...
# 9998   Ich denke dabei besonders an bestimmte in der ...
# 9999   Bekanntlich haben sich einige Mitgliedstaaten ...
# 10000  Ich denke auch an meine Region, wo mein Mitgli...
#
# [10001 rows x 2 columns]

# %%
df_sel=data_cleansing(df_selected)

# %%
df_sel
# Out:
#                                                  English  \
# 0                                  [resumption, session]
# 1      [declare, resumed, session, european, parliame...
# 2      [although, ,, seen, ,, dreaded, 'millennium, b...
# 3      [requested, debate, subject, course, next, day...
# 4      [meantime, ,, like, observe, minute, ', silenc...
# ...                                                  ...
# 9996   [example, ,, accept, new, roads, accept, new, ...
# 9997   [would, also, ask, commission, ensure, environ...
# 9998   [particularly, thinking, respect, certain, inf...
# 9999   [know, member, states, still, wavering, ,, exa...
# 10000  [however, ,, also, thinking, region, governmen...
#
#                                                   German
# 0                      [wiederaufnahme, sitzungsperiode]
# 1      [erkläre, freitag, ,, 17., dezember, unterbroc...
# 2      [feststellen, konnten, ,, gefürchtete, ``, mil...
# 3      [parlament, besteht, wunsch, aussprache, verla...
# 4      [heute, möchte, bitten, -, wunsch, kolleginnen...
# ...                                                  ...
# 9996   [beispiel, neue, straßen, akzeptiert, ,, akzep...
# 9997   [fordere, ,, kommission, projektauswahl, darau...
# 9998   [denke, dabei, besonders, bestimmte, planung, ...
# 9999   [bekanntlich, mitgliedstaaten, bahn, straße, d...
# 10000  [denke, region, ,, mitgliedstaat, eisenbahnstr...
#
# [10001 rows x 2 columns]

# %% [markdown]
# #### Feature Generation

# %%
# import string library function 
import string 
#get number of punctuation marks as feature
df_selected['PM_eng']=df_selected['English'].apply(lambda x: len([word for word in x if word in string.punctuation]))
df_selected['PM_ger']=df_selected['German'].apply(lambda x: len([word for word in x if word in string.punctuation]))
#get differences of punctuation marks absolute and relative with respect to smaller number as base
df_selected['PM_dif_abs']=np.abs(df_selected['PM_eng']-df_selected['PM_ger'])
df_selected['PM_dif_rel']=df_selected['PM_dif_abs']/np.minimum(df_selected['PM_eng'],df_selected['PM_ger'])
#set NaNs to zero
df_selected['PM_dif_rel'] = df_selected['PM_dif_rel'].replace(np.nan, 0)
#get number of words as feature
df_selected['Words_eng']=df_selected['English'].apply(lambda x: len([word for word in x if word not in string.punctuation]))
df_selected['Words_ger']=df_selected['German'].apply(lambda x: len([word for word in x if word not in string.punctuation]))
#get differences of words absolute and relative with respect to smaller number as base
df_selected['Words_dif_abs']=np.abs(df_selected['Words_eng']-df_selected['Words_ger'])
df_selected['Words_dif_rel']=df_selected['Words_dif_abs']/np.minimum(df_selected['Words_eng'],df_selected['Words_ger'])
#set NaNs to zero
df_selected['Words_dif_rel'] = df_selected['Words_dif_rel'].replace(np.nan, 0)

# %%
#number of question marks
marks='?'
df_selected['ger_ques']=df_selected['German'].apply(lambda x: len([word for word in x if word in marks]))
df_selected['eng_ques']=df_selected['English'].apply(lambda x: len([word for word in x if word in marks]))
#number of exclamation marks
marks='!'
df_selected['ger_exc']=df_selected['German'].apply(lambda x: len([word for word in x if word in marks]))
df_selected['eng_exc']=df_selected['English'].apply(lambda x: len([word for word in x if word in marks]))

# %%
#get number of characters in words and the average char per word
df_selected['char_eng']=df_selected['English'].apply(lambda x: len(str([word for word in x if word not in string.punctuation])))
df_selected['char_eng_avg']=df_selected['char_eng']/df_selected['Words_eng']
df_selected['char_ger']=df_selected['German'].apply(lambda x: len(str([word for word in x if word not in string.punctuation])))
df_selected['char_ger_avg']=df_selected['char_ger']/df_selected['Words_ger']
#absolute difference between avg
df_selected['char_avg_abs']=df_selected['char_ger_avg']-df_selected['char_eng_avg']

# %%
#use pos-tagger and get number of nouns, verbs, adjectives, tagset universal to only get the highest categories and 
df_selected['English_pos']=df_selected.apply(lambda x: nltk.pos_tag(x['English'],tagset='universal'), axis=1)

#pos-tagging with nltk not suppored in german yet -> use pretrained model for german as tagger
##pretrained model for german as tagger
#Christian Wartena (2019). A Probabilistic Morphology Model for German Lemmatization. In: Proceedings of the 15th Conference on Natural Language Processing (KONVENS 2019): Long Papers. Pp. 40-49, Erlangen.

tagger = ht.HanoverTagger('morphmodel_ger.pgz')
ger_pos=[]
for i in df_selected.itertuples():
    ger_pos.append(list(map(lambda x: tagger.analyze(x),i.German)))
df_selected['German_pos']=ger_pos

# %%
# df_selected.to_csv('Feature_Generation.csv',index=False)

# %%
# count=[]
# universal_pos=['ADJ','ADP','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB','X']
# for i in df_selected.itertuples():
#     count.append(nltk.FreqDist(tag for (word, tag) in i.German_pos).most_common())
# print(universal_pos)
# Out:
# ['ADJ', 'ADP', 'ADV', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRT', 'PRON', 'VERB', 'X']

# %%
df_selected=pd.read_csv('Feature_Generation.csv')

# %%
df_selected
# Out:
#                                                  English  \
# 0                              ['resumption', 'session']
# 1      ['declare', 'resumed', 'session', 'european', ...
# 2      ['although', ',', 'seen', ',', 'dreaded', "'mi...
# 3      ['requested', 'debate', 'subject', 'course', '...
# 4      ['meantime', ',', 'like', 'observe', 'minute',...
# ...                                                  ...
# 9996   ['example', ',', 'accept', 'new', 'roads', 'ac...
# 9997   ['would', 'also', 'ask', 'commission', 'ensure...
# 9998   ['particularly', 'thinking', 'respect', 'certa...
# 9999   ['know', 'member', 'states', 'still', 'waverin...
# 10000  ['however', ',', 'also', 'thinking', 'region',...
#
#                                                   German  PM_eng  PM_ger  \
# 0                  ['wiederaufnahme', 'sitzungsperiode']       0       0
# 1      ['erkläre', 'freitag', ',', '17.', 'dezember',...       2       4
# 2      ['feststellen', 'konnten', ',', 'gefürchtete',...       5       3
# 3      ['parlament', 'besteht', 'wunsch', 'aussprache...       2       1
# 4      ['heute', 'möchte', 'bitten', '-', 'wunsch', '...       7       6
# ...                                                  ...     ...     ...
# 9996   ['beispiel', 'neue', 'straßen', 'akzeptiert', ...       4       5
# 9997   ['fordere', ',', 'kommission', 'projektauswahl...       2       5
# 9998   ['denke', 'dabei', 'besonders', 'bestimmte', '...       1       1
# 9999   ['bekanntlich', 'mitgliedstaaten', 'bahn', 'st...       4       1
# 10000  ['denke', 'region', ',', 'mitgliedstaat', 'eis...       3       4
#
#        PM_dif_abs  PM_dif_rel  Words_eng  Words_ger  Words_dif_abs  \
# 0               0    0.000000          2          2              0
# 1               2    1.000000         21         16              5
# 2               2    0.666667         17         14              3
# 3               1    1.000000          7          8              1
# 4               1    0.166667         18         15              3
# ...           ...         ...        ...        ...            ...
# 9996            1    0.250000         19         18              1
# 9997            3    1.500000         22         19              3
# 9998            0    0.000000          6          7              1
# 9999            3    3.000000         14         11              3
# 10000           1    0.333333         14          9              5
#
#        Words_dif_rel  ...  eng_ques  ger_exc  eng_exc  char_eng  char_eng_avg  \
# 0           0.000000  ...         0        0        0        25     12.500000
# 1           0.312500  ...         0        0        0       209      9.952381
# 2           0.214286  ...         0        0        0       187     11.000000
# 3           0.142857  ...         0        0        0        76     10.857143
# 4           0.200000  ...         0        0        0       203     11.277778
# ...              ...  ...       ...      ...      ...       ...           ...
# 9996        0.055556  ...         0        0        0       196     10.315789
# 9997        0.157895  ...         0        0        0       235     10.681818
# 9998        0.166667  ...         0        0        0        85     14.166667
# 9999        0.272727  ...         0        0        0       139      9.928571
# 10000       0.555556  ...         0        0        0       145     10.357143
#
#        char_ger  char_ger_avg  char_avg_abs  \
# 0            37     18.500000      6.000000
# 1           205     12.812500      2.860119
# 2           184     13.142857      2.142857
# 3            99     12.375000      1.517857
# 4           185     12.333333      1.055556
# ...         ...           ...           ...
# 9996        214     11.888889      1.573099
# 9997        244     12.842105      2.160287
# 9998         89     12.714286     -1.452381
# 9999        146     13.272727      3.344156
# 10000       102     11.333333      0.976190
#
#                                              English_pos  \
# 0          [('resumption', 'NOUN'), ('session', 'NOUN')]
# 1      [('declare', 'NOUN'), ('resumed', 'VERB'), ('s...
# 2      [('although', 'ADP'), (',', '.'), ('seen', 'VE...
# 3      [('requested', 'VERB'), ('debate', 'NOUN'), ('...
# 4      [('meantime', 'ADV'), (',', '.'), ('like', 'AD...
# ...                                                  ...
# 9996   [('example', 'NOUN'), (',', '.'), ('accept', '...
# 9997   [('would', 'VERB'), ('also', 'ADV'), ('ask', '...
# 9998   [('particularly', 'ADV'), ('thinking', 'VERB')...
# 9999   [('know', 'ADJ'), ('member', 'NOUN'), ('states...
# 10000  [('however', 'ADV'), (',', '.'), ('also', 'ADV...
#
#                                               German_pos
# 0      [('Wiederaufnahme', 'NN'), ('Sitzungsperiode',...
# 1      [('erklären', 'VVFIN'), ('Freitag', 'NN'), ('-...
# 2      [('feststellen', 'VVINF'), ('können', 'VMFIN')...
# 3      [('Parlament', 'NN'), ('bestehen', 'VVPP'), ('...
# 4      [('heute', 'ADV'), ('möchten', 'VMFIN'), ('bit...
# ...                                                  ...
# 9996   [('Beispiel', 'NN'), ('neu', 'ADJA'), ('Straße...
# 9997   [('fordern', 'VVFIN'), ('--', '$,'), ('Kommiss...
# 9998   [('denken', 'VVFIN'), ('dabei', 'PROAV'), ('be...
# 9999   [('bekanntlich', 'ADV'), ('Mitgliedstaat', 'NN...
# 10000  [('denken', 'VVFIN'), ('Region', 'NN'), ('--',...
#
# [10001 rows x 21 columns]

# %%
universal_pos=['ADJ','ADP','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB','X']
for u_tag in universal_pos:
    df_selected[f'en_{u_tag}'] = df_selected['English_pos'].apply(lambda row: nltk.FreqDist(tag for (word, tag) in row if tag==u_tag)[u_tag])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c82334bfbe95> in <module>
#       1 universal_pos=['ADJ','ADP','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB','X']
#       2 for u_tag in universal_pos:
# ----> 3     df_selected[f'en_{u_tag}'] = df_selected['English_pos'].apply(lambda row: nltk.FreqDist(tag for (word, tag) in row if tag==u_tag)[u_tag])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-c82334bfbe95> in <lambda>(row)
#       1 universal_pos=['ADJ','ADP','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB','X']
#       2 for u_tag in universal_pos:
# ----> 3     df_selected[f'en_{u_tag}'] = df_selected['English_pos'].apply(lambda row: nltk.FreqDist(tag for (word, tag) in row if tag==u_tag)[u_tag])
#
# ~\anaconda3\lib\site-packages\nltk\probability.py in __init__(self, samples)
#     102         :type samples: Sequence
#     103         """
# --> 104         Counter.__init__(self, samples)
#     105
#     106         # Cached number of samples in this FreqDist
#
# ~\anaconda3\lib\collections\__init__.py in __init__(self, iterable, **kwds)
#     550         '''
#     551         super(Counter, self).__init__()
# --> 552         self.update(iterable, **kwds)
#     553
#     554     def __missing__(self, key):
#
# ~\anaconda3\lib\site-packages\nltk\probability.py in update(self, *args, **kwargs)
#     140         """
#     141         self._N = None
# --> 142         super(FreqDist, self).update(*args, **kwargs)
#     143
#     144     def setdefault(self, key, val):
#
# ~\anaconda3\lib\collections\__init__.py in update(self, iterable, **kwds)
#     635                     super(Counter, self).update(iterable) # fast path when counter is empty
#     636             else:
# --> 637                 _count_elements(self, iterable)
#     638         if kwds:
#     639             self.update(kwds)
#
# <ipython-input-7-c82334bfbe95> in <genexpr>(.0)
#       1 universal_pos=['ADJ','ADP','ADV','CONJ','DET','NOUN','NUM','PRT','PRON','VERB','X']
#       2 for u_tag in universal_pos:
# ----> 3     df_selected[f'en_{u_tag}'] = df_selected['English_pos'].apply(lambda row: nltk.FreqDist(tag for (word, tag) in row if tag==u_tag)[u_tag])
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# Out:
#                                                  English  \
# 0                                  [resumption, session]
# 1      [declare, resumed, session, european, parliame...
# 2      [although, ,, seen, ,, dreaded, 'millennium, b...
# 3      [requested, debate, subject, course, next, day...
# 4      [meantime, ,, like, observe, minute, ', silenc...
# ...                                                  ...
# 9996   [example, ,, accept, new, roads, accept, new, ...
# 9997   [would, also, ask, commission, ensure, environ...
# 9998   [particularly, thinking, respect, certain, inf...
# 9999   [know, member, states, still, wavering, ,, exa...
# 10000  [however, ,, also, thinking, region, governmen...
#
#                                                   German  PM_eng  PM_ger  \
# 0                      [wiederaufnahme, sitzungsperiode]       0       0
# 1      [erkläre, freitag, ,, 17., dezember, unterbroc...       2       4
# 2      [feststellen, konnten, ,, gefürchtete, ``, mil...       5       3
# 3      [parlament, besteht, wunsch, aussprache, verla...       2       1
# 4      [heute, möchte, bitten, -, wunsch, kolleginnen...       7       6
# ...                                                  ...     ...     ...
# 9996   [beispiel, neue, straßen, akzeptiert, ,, akzep...       4       5
# 9997   [fordere, ,, kommission, projektauswahl, darau...       2       5
# 9998   [denke, dabei, besonders, bestimmte, planung, ...       1       1
# 9999   [bekanntlich, mitgliedstaaten, bahn, straße, d...       4       1
# 10000  [denke, region, ,, mitgliedstaat, eisenbahnstr...       3       4
#
#        PM_dif_abs  PM_dif_rel  Words_eng  Words_ger  Words_dif_abs  \
# 0               0    0.000000          2          2              0
# 1               2    1.000000         21         16              5
# 2               2    0.666667         17         14              3
# 3               1    1.000000          7          8              1
# 4               1    0.166667         18         15              3
# ...           ...         ...        ...        ...            ...
# 9996            1    0.250000         19         18              1
# 9997            3    1.500000         22         19              3
# 9998            0    0.000000          6          7              1
# 9999            3    3.000000         14         11              3
# 10000           1    0.333333         14          9              5
#
#        Words_dif_rel  ...  en_ADP  en_ADV  en_CONJ  en_DET  en_NOUN  en_NUM  \
# 0           0.000000  ...       0       0        0       0        2       0
# 1           0.312500  ...       0       1        0       0        6       2
# 2           0.214286  ...       1       2        0       0        7       1
# 3           0.142857  ...       0       0        0       0        4       0
# 4           0.200000  ...       1       2        0       0        9       0
# ...              ...  ...     ...     ...      ...     ...      ...     ...
# 9996        0.055556  ...       1       1        0       0       10       0
# 9997        0.157895  ...       0       1        0       0        9       0
# 9998        0.166667  ...       0       1        0       0        3       0
# 9999        0.272727  ...       0       1        0       0        8       0
# 10000       0.555556  ...       1       3        0       0        6       0
#
#        en_PRT  en_PRON  en_VERB en_X
# 0           0        0        0    0
# 1           0        0        7    0
# 2           0        0        4    0
# 3           0        0        1    0
# 4           0        0        3    0
# ...       ...      ...      ...  ...
# 9996        0        0        4    0
# 9997        1        0        8    0
# 9998        0        0        1    0
# 9999        0        0        2    0
# 10000       0        0        2    0
#
# [10001 rows x 33 columns]

# %%
count
# Out:
# [[('NN', 2)],
#  [('NN', 6),
#   ('ADJA', 4),
#   ('VVFIN', 3),
#   ('$,', 3),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('FM', 2),
#   ('$.', 2),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('PPOSAT', 1),
#   ('VAPP', 1)],
#  [('NN', 5), ('VVPP', 1), ('VVFIN', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 8),
#   ('$,', 3),
#   ('ADV', 2),
#   ('$(', 2),
#   ('ADJA', 2),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('ADV', 1), ('$,', 1), ('NN', 1), ('VVINF', 1), ('$.', 1)],
#  [('$(', 2), ('NN', 2), ('VVPP', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 1), ('$.', 1)],
#  [('NN', 4),
#   ('NE', 2),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('NE', 4),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVFIN', 2),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('PIAT', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('$,', 5),
#   ('NE', 5),
#   ('VVINF', 4),
#   ('ADJA', 4),
#   ('VAFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('$,', 3),
#   ('ADV', 2),
#   ('NN', 2),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJD', 1), ('$,', 1), ('NE', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 1), ('$.', 1)],
#  [('NN', 4), ('VMFIN', 1), ('CARD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4), ('VVINF', 2), ('VVFIN', 1), ('$,', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 9),
#   ('$,', 4),
#   ('VVINF', 2),
#   ('ADJA', 1),
#   ('CARD', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('VMFIN', 1), ('APPR', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('ADJA', 3),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 5),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('PDS', 1),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('NN', 9),
#   ('ADJA', 5),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('ADV', 2),
#   ('NE', 2),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('$,', 5),
#   ('NN', 4),
#   ('ADJA', 1),
#   ('NE', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('PIAT', 1),
#   ('ADJD', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 13),
#   ('$,', 6),
#   ('ADJA', 5),
#   ('NE', 4),
#   ('ADV', 2),
#   ('ADJD', 2),
#   ('VVINF', 2),
#   ('APPR', 1),
#   ('VMFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('PIAT', 1),
#   ('VVFIN', 1),
#   ('NN', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('$,', 2),
#   ('NN', 2),
#   ('PIAT', 1),
#   ('APPR', 1),
#   ('NE', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADV', 2), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$.', 2),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVPP', 1)],
#  [('NN', 2), ('NE', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 2),
#   ('VVPP', 2),
#   ('VVINF', 1),
#   ('ADJD', 1),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 3), ('$,', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 4),
#   ('$,', 3),
#   ('ADJD', 2),
#   ('PIAT', 1),
#   ('VVPP', 1),
#   ('$(', 1),
#   ('ADV', 1),
#   ('TRUNC', 1),
#   ('NE', 1),
#   ('VVIZU', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('$,', 4),
#   ('ADJA', 2),
#   ('NE', 2),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 2),
#   ('VVPP', 2),
#   ('ADJA', 2),
#   ('ADJD', 2),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('$,', 2), ('ADV', 1), ('VAFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 4),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('VVPP', 2),
#   ('CARD', 1),
#   ('VMFIN', 1),
#   ('PROAV', 1)],
#  [('PROAV', 2),
#   ('VVINF', 2),
#   ('$,', 2),
#   ('NN', 2),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 5), ('NE', 2), ('$,', 2), ('VVINF', 1), ('VVFIN', 1), ('$.', 1)],
#  [('VVFIN', 1), ('$,', 1), ('NN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('VVINF', 1),
#   ('PWAV', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('PWAV', 1),
#   ('VAFIN', 1),
#   ('APPR', 1),
#   ('PPOSAT', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('PWAV', 1),
#   ('NN', 1),
#   ('APPR', 1),
#   ('CARD', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3), ('PWAV', 1), ('KON', 1), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('PWAV', 1), ('VVINF', 1), ('NN', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 3), ('PWAV', 1), ('VAFIN', 1), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 2), ('PWAV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 2), ('$,', 2), ('VVINF', 2), ('$.', 1)],
#  [('$,', 3),
#   ('NN', 2),
#   ('ADJD', 2),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('VVINF', 4),
#   ('$,', 4),
#   ('$.', 2),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('PROAV', 1)],
#  [('NN', 8),
#   ('NE', 4),
#   ('$,', 3),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('VVPP', 1)],
#  [('NN', 4),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('$,', 2), ('NN', 2), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 4),
#   ('NE', 3),
#   ('VVPP', 1),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('ADV', 1), ('NN', 1), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 2),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('ADJD', 1), ('VVINF', 1), ('$,', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 12),
#   ('$,', 5),
#   ('ADJA', 3),
#   ('NE', 3),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('PPOSAT', 1),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('VVINF', 1),
#   ('KOUS', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 3), ('VVFIN', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 4), ('$,', 2), ('ADJA', 2), ('VVFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4), ('APPR', 1), ('ADJD', 1), ('$.', 1)],
#  [('ADV', 2),
#   ('NE', 2),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$,', 1),
#   ('NN', 1),
#   ('$.', 1)],
#  [('VVPP', 1), ('ADV', 1), ('NN', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 4),
#   ('PWAV', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADV', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 1)],
#  [('NN', 10),
#   ('$,', 2),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('CARD', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVINF', 1), ('$.', 1)],
#  [('NN', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 3),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('CARD', 1),
#   ('KON', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 3),
#   ('NE', 2),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('KOUS', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('PROAV', 3), ('NN', 2), ('$.', 2), ('ADJD', 1), ('$,', 1)],
#  [('NN', 17),
#   ('ADJA', 5),
#   ('NE', 3),
#   ('VVFIN', 3),
#   ('$.', 2),
#   ('$,', 2),
#   ('PTKVZ', 1)],
#  [('NN', 9),
#   ('ADJA', 3),
#   ('ADV', 2),
#   ('$,', 2),
#   ('ADJD', 2),
#   ('VVPP', 1),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('NN', 13),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('ADJA', 2),
#   ('ADV', 2),
#   ('$.', 2),
#   ('VVFIN', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('NE', 1)],
#  [('NN', 5), ('$,', 3), ('ADV', 2), ('VVINF', 2), ('PIAT', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJD', 2),
#   ('$,', 2),
#   ('VVFIN', 1),
#   ('VAFIN', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 16),
#   ('$(', 3),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('PWAV', 1),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('KON', 1),
#   ('$,', 1),
#   ('VVIZU', 1)],
#  [('NN', 3), ('$.', 1)],
#  [('NN', 13),
#   ('$,', 8),
#   ('ADJD', 3),
#   ('NE', 2),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('$(', 1)],
#  [('NN', 25),
#   ('$,', 10),
#   ('ADJA', 5),
#   ('VVINF', 5),
#   ('PROAV', 4),
#   ('ADV', 3),
#   ('VVFIN', 3),
#   ('$(', 2),
#   ('APZR', 1),
#   ('VVPP', 1),
#   ('PWAV', 1),
#   ('VMFIN', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 16),
#   ('$,', 8),
#   ('VVINF', 5),
#   ('VVIZU', 2),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('PPOSAT', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 20),
#   ('$,', 11),
#   ('ADV', 5),
#   ('VVPP', 4),
#   ('VVFIN', 4),
#   ('VVINF', 4),
#   ('PROAV', 2),
#   ('ADJA', 2),
#   ('NE', 2),
#   ('VVIZU', 2),
#   ('VMFIN', 2),
#   ('$.', 2)],
#  [('$,', 4), ('NN', 4), ('VVINF', 3), ('PROAV', 2), ('ADV', 1), ('$.', 1)],
#  [('$(', 2), ('NN', 2)],
#  [('NN', 10), ('$,', 3), ('VVPP', 3), ('$.', 2), ('NE', 2)],
#  [('NN', 5),
#   ('NE', 2),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('VVFIN', 3), ('$.', 2), ('ADV', 2), ('$,', 1), ('VVINF', 1)],
#  [('NN', 1), ('NE', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('VVINF', 2), ('NN', 1), ('$,', 1), ('$.', 1)],
#  [('VVPP', 1), ('$.', 1)],
#  [('NN', 4),
#   ('KON', 1),
#   ('ADV', 1),
#   ('PIAT', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('$.', 2), ('CARD', 2), ('VVPP', 1), ('VVINF', 1), ('PIAT', 1)],
#  [('NN', 6),
#   ('$,', 5),
#   ('$(', 2),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 1), ('$.', 1)],
#  [('NN', 1), ('$.', 1)],
#  [('VMFIN', 1), ('NN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 4),
#   ('NE', 4),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('PPOSAT', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 11),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('APPR', 2),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 4), ('CARD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('VVPP', 1),
#   ('FM', 1),
#   ('NE', 1),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('VVPP', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 3),
#   ('ADV', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5), ('$.', 2), ('$,', 2), ('VVFIN', 1), ('VMFIN', 1)],
#  [('NN', 3), ('VMFIN', 1), ('$,', 1), ('ADJD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 2), ('VVFIN', 2), ('VVINF', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 17),
#   ('$,', 5),
#   ('$(', 4),
#   ('VVINF', 3),
#   ('PROAV', 2),
#   ('CARD', 2),
#   ('VVPP', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVFIN', 1),
#   ('PIAT', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('PTKVZ', 1),
#   ('$.', 1)],
#  [('$(', 2), ('NN', 2)],
#  [('NN', 6), ('$,', 3), ('ADJA', 2), ('VVINF', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('$(', 2), ('$.', 2), ('VVFIN', 1), ('PTKVZ', 1)],
#  [('NN', 5), ('VVFIN', 1), ('ADJD', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 3), ('VVPP', 1), ('$,', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 3), ('VMFIN', 1), ('PIS', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 15),
#   ('ADJA', 4),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('VVPP', 2),
#   ('PIS', 1),
#   ('$(', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('ADV', 3),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('PROAV', 1), ('VVPP', 1), ('$,', 1), ('VVIZU', 1), ('$.', 1)],
#  [('PIAT', 1), ('APPR', 1), ('$,', 1), ('NN', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 2), ('VVINF', 1), ('NE', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 4),
#   ('ADV', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 3),
#   ('VVFIN', 2),
#   ('$.', 2),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('ADJD', 1)],
#  [('$,', 2), ('VVFIN', 1), ('NN', 1), ('ADJA', 1), ('$.', 1)],
#  [('$,', 7),
#   ('PROAV', 5),
#   ('NN', 5),
#   ('VVPP', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('VVIZU', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('PIAT', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 13),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('ADV', 2),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('VVIZU', 1),
#   ('PIAT', 1),
#   ('VAFIN', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('VVINF', 1),
#   ('PTKVZ', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('CARD', 3),
#   ('$(', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('PTKVZ', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('VVINF', 2),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('APPR', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('PIAT', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 3), ('$.', 2), ('VVPP', 1), ('VAPP', 1)],
#  [('VMFIN', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('NN', 1),
#   ('$.', 1)],
#  [('FM', 2), ('PROAV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 3), ('VVFIN', 2), ('PIAT', 1), ('VVPP', 1), ('$(', 1)],
#  [('NN', 5), ('$.', 2), ('ADJD', 1)],
#  [('NN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 12),
#   ('$,', 3),
#   ('$(', 2),
#   ('VVINF', 2),
#   ('ADJA', 1),
#   ('PROAV', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('VVFIN', 1), ('$.', 1)],
#  [('NN', 7), ('$,', 2), ('VVINF', 1), ('VAFIN', 1), ('VVIZU', 1), ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('$,', 3),
#   ('ADJA', 3),
#   ('ADV', 2),
#   ('VVPP', 2),
#   ('NN', 2),
#   ('VAFIN', 1),
#   ('ADJD', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 6), ('$.', 2), ('VVINF', 2), ('$,', 2), ('NE', 2), ('VVPP', 1)],
#  [('ADJD', 1), ('$.', 1)],
#  [('$,', 3),
#   ('NN', 3),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('VAPP', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('NE', 2), ('VVFIN', 1), ('$,', 1), ('$.', 1)],
#  [('VVPP', 2), ('$,', 1), ('APPRART', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 2), ('ADJD', 1), ('VAPP', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 4),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('ADJD', 2),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('VVFIN', 1), ('NN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 3), ('ADV', 2), ('PIAT', 1), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('VVFIN', 1), ('ADJD', 1), ('ADV', 1), ('NN', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 2), ('NE', 2), ('$,', 2), ('ADJD', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('$,', 3), ('NN', 3), ('VVINF', 2), ('VVFIN', 1), ('KOUS', 1), ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('$.', 2), ('APPRART', 1), ('VVINF', 1), ('ADV', 1)],
#  [('NN', 2),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('$(', 2), ('NN', 2), ('VVPP', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 2)],
#  [('NN', 24),
#   ('$(', 7),
#   ('CARD', 3),
#   ('ADJA', 3),
#   ('$,', 2),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 16), ('VVFIN', 3), ('$,', 3), ('$.', 2), ('ADJA', 2), ('ADJD', 1)],
#  [('NN', 11),
#   ('ADJD', 4),
#   ('$,', 4),
#   ('ADV', 2),
#   ('$.', 2),
#   ('KON', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVPP', 1),
#   ('VVIZU', 1)],
#  [('NN', 13),
#   ('ADJA', 4),
#   ('$.', 3),
#   ('$(', 3),
#   ('ADV', 2),
#   ('NE', 2),
#   ('KON', 2),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('APPRART', 1),
#   ('XY', 1),
#   ('APPR', 1)],
#  [('NN', 8),
#   ('ADJA', 5),
#   ('$,', 4),
#   ('ADV', 3),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 2), ('PIAT', 1), ('ADJD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 2), ('ADJA', 1), ('VVFIN', 1), ('ADJD', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 3),
#   ('ADJA', 3),
#   ('VAFIN', 2),
#   ('VVPP', 2),
#   ('$.', 2),
#   ('ADJD', 1),
#   ('ADV', 1),
#   ('KON', 1),
#   ('VVFIN', 1)],
#  [('NN', 7),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('VVPP', 2),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('ADV', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 14),
#   ('ADJA', 10),
#   ('$,', 6),
#   ('VVINF', 4),
#   ('ADV', 3),
#   ('$.', 2),
#   ('NE', 2),
#   ('VMFIN', 1),
#   ('PRELS', 1),
#   ('APPR', 1),
#   ('PTKA', 1),
#   ('VAPP', 1)],
#  [('NN', 9),
#   ('ADJA', 5),
#   ('$,', 4),
#   ('VVPP', 3),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('PIAT', 1),
#   ('VMFIN', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('NE', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 4),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('PIAT', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADJA', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 5),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('VMFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('$,', 4),
#   ('ADJD', 3),
#   ('VMFIN', 2),
#   ('PROAV', 2),
#   ('VVINF', 2),
#   ('NN', 2),
#   ('VVPP', 2),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('VVINF', 4),
#   ('VMFIN', 2),
#   ('$.', 2),
#   ('$,', 2),
#   ('ADJA', 1),
#   ('PIS', 1),
#   ('PROAV', 1),
#   ('APPRART', 1),
#   ('NE', 1),
#   ('ADV', 1)],
#  [('NN', 8),
#   ('ADV', 5),
#   ('ADJA', 3),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('VVIZU', 1),
#   ('NE', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 10), ('$,', 2), ('VVPP', 1), ('ADJA', 1), ('ADJD', 1), ('$.', 1)],
#  [('VVFIN', 1), ('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 17),
#   ('$,', 8),
#   ('ADJA', 5),
#   ('ADJD', 5),
#   ('VVFIN', 3),
#   ('$.', 3),
#   ('NE', 3),
#   ('CARD', 2),
#   ('APPR', 1),
#   ('PRELS', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('PDS', 1),
#   ('VMFIN', 1)],
#  [('NN', 8),
#   ('ADJA', 5),
#   ('CARD', 2),
#   ('VVFIN', 1),
#   ('PTKVZ', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 3),
#   ('VVINF', 2),
#   ('PROAV', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('PIS', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADV', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('ADJA', 1), ('VVINF', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 3),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('KON', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVFIN', 1), ('$,', 1), ('ADV', 1), ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 10),
#   ('ADJA', 4),
#   ('$,', 3),
#   ('ADJD', 2),
#   ('ADV', 2),
#   ('VVFIN', 1),
#   ('APPR', 1),
#   ('KON', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('VVFIN', 2),
#   ('ADV', 2),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('PWAV', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1)],
#  [('NN', 9),
#   ('$,', 4),
#   ('ADJA', 2),
#   ('VVPP', 2),
#   ('$.', 2),
#   ('ADV', 2),
#   ('NE', 2),
#   ('APPR', 2),
#   ('VAFIN', 2),
#   ('VVFIN', 1),
#   ('ADJD', 1)],
#  [('NN', 4),
#   ('VVINF', 2),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('APPR', 1),
#   ('PRELS', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 4),
#   ('$,', 2),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('CARD', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('ADV', 1), ('$,', 1), ('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 6), ('ADJD', 2), ('VVFIN', 1), ('$,', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADJD', 2),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5), ('KON', 1), ('VVINF', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 7),
#   ('VVPP', 1),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('NE', 1),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('NN', 2), ('ADJA', 1), ('VVPP', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('VVINF', 1), ('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 3),
#   ('$,', 3),
#   ('CARD', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('PTKVZ', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('PROAV', 1), ('VVINF', 1), ('ADJD', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 9),
#   ('$,', 3),
#   ('VVINF', 3),
#   ('ADJD', 2),
#   ('ADV', 2),
#   ('KOUS', 1),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 5), ('$,', 1), ('VVPP', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJD', 2),
#   ('$,', 2),
#   ('VVPP', 2),
#   ('ADJA', 1),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('PTKVZ', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 2),
#   ('VVFIN', 1),
#   ('PROAV', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('$,', 2),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('ADJA', 3),
#   ('VVPP', 2),
#   ('PDS', 1),
#   ('$,', 1),
#   ('KOUS', 1),
#   ('ADJD', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('ADV', 1), ('VVFIN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADJD', 2),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('$,', 4),
#   ('$.', 2),
#   ('ADV', 2),
#   ('ADJA', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1)],
#  [('VMFIN', 1), ('PIAT', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 10),
#   ('$,', 5),
#   ('VVFIN', 4),
#   ('$(', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('ADJD', 4),
#   ('VVFIN', 2),
#   ('$,', 2),
#   ('$(', 2),
#   ('ADJA', 1),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('PWAV', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 2), ('$.', 2), ('ADJA', 1), ('VAFIN', 1), ('ADV', 1), ('VVPP', 1)],
#  [('NN', 4),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('PIAT', 1),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NE', 4),
#   ('NN', 3),
#   ('ADV', 2),
#   ('$,', 2),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4), ('$,', 2), ('ADJD', 2), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('KOUS', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('PIS', 1),
#   ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('VAFIN', 1), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VVFIN', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('FM', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVINF', 2), ('ADJD', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 23),
#   ('ADJA', 4),
#   ('$,', 4),
#   ('$.', 3),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('VVFIN', 1)],
#  [('NN', 11),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('ADJA', 2),
#   ('$(', 2),
#   ('PPOSAT', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('ADJA', 6),
#   ('$,', 5),
#   ('ADJD', 3),
#   ('VAFIN', 2),
#   ('VVINF', 2),
#   ('ADV', 2),
#   ('VVPP', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('ADJD', 4),
#   ('NN', 2),
#   ('$,', 2),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6), ('NE', 1), ('$,', 1), ('ADJD', 1), ('VMFIN', 1), ('$.', 1)],
#  [('NN', 11),
#   ('$,', 3),
#   ('VMFIN', 2),
#   ('ADJD', 2),
#   ('VVINF', 2),
#   ('NE', 2),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('FM', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('ADJA', 1),
#   ('PWAV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('ADJD', 1), ('$.', 1)],
#  [('NN', 6), ('$,', 2), ('VVFIN', 2), ('PIAT', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 4),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('VVFIN', 2),
#   ('VVINF', 2),
#   ('APPR', 1),
#   ('NE', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVINF', 1), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 10),
#   ('VVINF', 4),
#   ('$,', 3),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('ADJA', 1)],
#  [('ADV', 3),
#   ('NN', 3),
#   ('$,', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('APPR', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('VVFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('ADV', 1), ('CARD', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 2)],
#  [('NN', 19),
#   ('$(', 10),
#   ('CARD', 5),
#   ('NE', 3),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 21),
#   ('$,', 5),
#   ('ADJA', 4),
#   ('$.', 2),
#   ('ADJD', 2),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('CARD', 1),
#   ('PDS', 1)],
#  [('NN', 5), ('ADJA', 2), ('VVINF', 1), ('ADV', 1), ('$.', 1)],
#  [('ADJA', 2),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('APPR', 1),
#   ('NN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('$,', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('NN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADV', 2), ('ADJA', 2), ('VVFIN', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 9),
#   ('ADJA', 5),
#   ('$,', 4),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 7), ('ADJA', 3), ('VVPP', 1), ('$.', 1)],
#  [('NN', 12),
#   ('ADJA', 4),
#   ('ADV', 3),
#   ('$,', 3),
#   ('VVFIN', 3),
#   ('NE', 2),
#   ('$(', 2),
#   ('VVPP', 1),
#   ('VVINF', 1),
#   ('FM', 1),
#   ('KON', 1),
#   ('XY', 1),
#   ('PIAT', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 6), ('ADV', 3), ('$.', 2), ('VVFIN', 1), ('VVINF', 1)],
#  [('NN', 3), ('VVFIN', 2), ('$,', 1), ('ADJA', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('PROAV', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 1),
#   ('VAFIN', 1),
#   ('CARD', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('ADV', 3),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('CARD', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('CARD', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('ADJD', 3),
#   ('VMFIN', 2),
#   ('VVINF', 1),
#   ('PROAV', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('ADJA', 1),
#   ('APPR', 1),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('NN', 2), ('PROAV', 1), ('APZR', 1), ('VVFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('VVPP', 2),
#   ('NE', 2),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('FM', 1),
#   ('KON', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('ADJA', 2), ('NN', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVPP', 2),
#   ('VVINF', 1),
#   ('ADJD', 1),
#   ('CARD', 1),
#   ('NE', 1),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('VVFIN', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADV', 3), ('$,', 2), ('ADJD', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 3), ('$.', 2), ('ADJA', 1)],
#  [('NN', 5),
#   ('VVFIN', 4),
#   ('ADJA', 4),
#   ('ADJD', 4),
#   ('ADV', 3),
#   ('$.', 2),
#   ('$,', 2),
#   ('PIS', 1),
#   ('CARD', 1)],
#  [('NN', 7), ('VMFIN', 1), ('ADJD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 9),
#   ('$,', 5),
#   ('ADV', 4),
#   ('VVINF', 4),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 4), ('ADV', 2), ('VVPP', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VVPP', 2),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('NE', 1),
#   ('$,', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('VAFIN', 1), ('CARD', 1), ('FM', 1), ('ADJD', 1), ('$.', 1)],
#  [('NE', 2),
#   ('ADJD', 2),
#   ('NN', 2),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NE', 2), ('NN', 2), ('ADJD', 1), ('$,', 1), ('VMFIN', 1), ('$.', 1)],
#  [('NN', 2),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('CARD', 1),
#   ('FM', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('VAFIN', 1),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVFIN', 2), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('ADV', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('VVFIN', 1), ('ADV', 1), ('ADJD', 1), ('$.', 1)],
#  [('$,', 6),
#   ('NN', 4),
#   ('VVFIN', 3),
#   ('$.', 2),
#   ('NE', 2),
#   ('ADV', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('ADJD', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('$,', 2), ('NN', 2), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('$,', 7),
#   ('NN', 6),
#   ('PROAV', 2),
#   ('ADJD', 2),
#   ('VVINF', 2),
#   ('VVPP', 2),
#   ('NE', 1),
#   ('APPR', 1),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('VVINF', 2),
#   ('$(', 2),
#   ('$,', 2),
#   ('ADV', 2),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('CARD', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('ADV', 2),
#   ('ADJA', 2),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('ADV', 3),
#   ('VVINF', 3),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 3),
#   ('$,', 2),
#   ('NE', 1),
#   ('VVPP', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('ADJD', 2), ('VVINF', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('$.', 1)],
#  [('ADJA', 3),
#   ('NN', 3),
#   ('ADV', 2),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('VVINF', 2),
#   ('ADJD', 2),
#   ('$.', 2),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('XY', 1),
#   ('NE', 1)],
#  [('NN', 2), ('ADJA', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 5), ('VVINF', 2), ('$,', 1), ('ADJA', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 4), ('VMFIN', 1), ('APPR', 1), ('CARD', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 5), ('$,', 3), ('ADJD', 3), ('VVFIN', 2), ('VVINF', 1), ('$.', 1)],
#  [('NN', 9),
#   ('$,', 3),
#   ('ADJD', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('PTKVZ', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('NE', 2),
#   ('ADJA', 2),
#   ('VVPP', 2),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 4),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('VMFIN', 1),
#   ('PIAT', 1),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVFIN', 2),
#   ('ADJD', 1),
#   ('APPR', 1),
#   ('PROAV', 1),
#   ('APZR', 1)],
#  [('ADJA', 2),
#   ('ADV', 2),
#   ('ADJD', 2),
#   ('PROAV', 1),
#   ('$,', 1),
#   ('NN', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('$,', 2),
#   ('ADJD', 2),
#   ('ADV', 1),
#   ('VAFIN', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('$.', 2),
#   ('VVFIN', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADJD', 1)],
#  [('NN', 9), ('ADJA', 6), ('$,', 2), ('$(', 2), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 2),
#   ('CARD', 2),
#   ('PIAT', 1),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 11),
#   ('ADJA', 6),
#   ('$,', 5),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('ADJD', 2),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 5),
#   ('VVINF', 4),
#   ('ADJA', 3),
#   ('ADJD', 2),
#   ('VAFIN', 2),
#   ('NE', 1),
#   ('VMFIN', 1),
#   ('APPR', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 14),
#   ('$,', 6),
#   ('ADV', 2),
#   ('VVPP', 2),
#   ('ADJA', 2),
#   ('VAPP', 1),
#   ('VVINF', 1),
#   ('APPRART', 1),
#   ('VVFIN', 1),
#   ('KON', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 5),
#   ('ADJA', 2),
#   ('NE', 1),
#   ('ADJD', 1),
#   ('CARD', 1),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('VVINF', 1), ('ADJA', 1), ('CARD', 1), ('NN', 1), ('$.', 1)],
#  [('VVFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('ADV', 1), ('CARD', 1), ('APPR', 1), ('$.', 1)],
#  [('NN', 2)],
#  [('NN', 18),
#   ('$(', 11),
#   ('CARD', 6),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('NE', 1)],
#  [('NN', 9),
#   ('$,', 6),
#   ('VVFIN', 4),
#   ('ADV', 4),
#   ('ADJA', 3),
#   ('ADJD', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('$,', 1),
#   ('VAFIN', 1),
#   ('ADJA', 1),
#   ('NE', 1),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 1),
#   ('PIAT', 1),
#   ('NE', 1),
#   ('PRELS', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('VVFIN', 2),
#   ('NN', 1),
#   ('NE', 1),
#   ('$,', 1),
#   ('PWAV', 1),
#   ('APPR', 1),
#   ('CARD', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADV', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 5), ('ADJA', 3), ('VVINF', 1), ('PROAV', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJD', 2),
#   ('$,', 2),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('PRELS', 1),
#   ('NE', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('ADJD', 2),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('$,', 1),
#   ('PRELS', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5), ('VVINF', 1), ('$,', 1), ('ADV', 1), ('VVFIN', 1), ('$.', 1)],
#  [('VVINF', 3),
#   ('ADJD', 3),
#   ('NN', 2),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVINF', 1), ('$,', 1), ('ADJA', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 9),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('VVIZU', 1),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADV', 2), ('VVINF', 2), ('$,', 1), ('$.', 1)],
#  [('$,', 2), ('NN', 2), ('VVFIN', 2), ('PIS', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 3), ('ADJA', 1), ('NE', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5), ('$.', 2), ('ADJA', 2), ('VVPP', 1), ('PIAT', 1)],
#  [('NN', 17),
#   ('$,', 6),
#   ('VVPP', 4),
#   ('VVINF', 3),
#   ('ADV', 2),
#   ('VMFIN', 2),
#   ('$.', 2),
#   ('ADJD', 2),
#   ('PWAV', 1),
#   ('ADJA', 1),
#   ('PRELS', 1)],
#  [('NN', 5), ('ADJA', 4), ('VVPP', 1), ('$,', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 13),
#   ('$,', 4),
#   ('ADV', 2),
#   ('VAFIN', 2),
#   ('VVPP', 2),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVFIN', 1), ('ADJA', 1), ('ADV', 1), ('PTKVZ', 1), ('$.', 1)],
#  [('NN', 12),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('PRELS', 1),
#   ('ADV', 1),
#   ('VAPP', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1)],
#  [('NN', 8),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 14),
#   ('ADJA', 5),
#   ('VAFIN', 3),
#   ('VVPP', 3),
#   ('$,', 2),
#   ('$.', 2),
#   ('ADV', 1),
#   ('NE', 1),
#   ('APPR', 1),
#   ('VVFIN', 1)],
#  [('NN', 15),
#   ('$,', 3),
#   ('ADJD', 3),
#   ('VMFIN', 2),
#   ('ADV', 2),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('NE', 1),
#   ('VVFIN', 1)],
#  [('NN', 9),
#   ('$,', 3),
#   ('CARD', 2),
#   ('VVPP', 2),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('NE', 3),
#   ('ADJA', 3),
#   ('FM', 2),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('VVFIN', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 5),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('VVINF', 3),
#   ('$,', 3),
#   ('PDS', 1),
#   ('KON', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('VVFIN', 2),
#   ('$,', 2),
#   ('NE', 1),
#   ('ADJD', 1),
#   ('KOUS', 1),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6), ('CARD', 2), ('VVINF', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('ADJA', 2),
#   ('CARD', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('VVFIN', 2),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('CARD', 1),
#   ('$.', 1)],
#  [('VVINF', 3),
#   ('$,', 3),
#   ('PROAV', 2),
#   ('VVFIN', 2),
#   ('NN', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 14), ('ADJA', 3), ('$,', 2), ('$.', 2)],
#  [('NN', 11),
#   ('ADJA', 6),
#   ('APPR', 3),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('NE', 1)],
#  [('NN', 5),
#   ('ADJA', 4),
#   ('ADJD', 3),
#   ('ADV', 1),
#   ('$,', 1),
#   ('PIS', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('VVINF', 3), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('PDS', 1),
#   ('APPR', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 6), ('ADJA', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('CARD', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVFIN', 1), ('CARD', 1), ('$.', 1)],
#  [('NN', 4),
#   ('PROAV', 1),
#   ('APZR', 1),
#   ('CARD', 1),
#   ('PPOSAT', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 30),
#   ('$,', 15),
#   ('ADJA', 13),
#   ('VVINF', 3),
#   ('NE', 2),
#   ('$.', 2),
#   ('ADV', 2),
#   ('VVFIN', 2),
#   ('VMFIN', 1),
#   ('APPR', 1),
#   ('KOUS', 1),
#   ('ADJD', 1)],
#  [('NN', 12),
#   ('ADJA', 4),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('PROAV', 2),
#   ('KON', 2),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('APPR', 1),
#   ('$.', 1)],
#  [('NN', 14),
#   ('$,', 4),
#   ('ADJA', 4),
#   ('CARD', 3),
#   ('VVINF', 2),
#   ('VVPP', 2),
#   ('ADJD', 1),
#   ('PRELS', 1),
#   ('ADV', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('ADJA', 3),
#   ('VMFIN', 2),
#   ('VVINF', 2),
#   ('$,', 2),
#   ('CARD', 2),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('$,', 4),
#   ('$.', 2),
#   ('VMFIN', 1),
#   ('APPR', 1),
#   ('ADJA', 1),
#   ('VVINF', 1)],
#  [('$,', 1), ('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 9),
#   ('ADV', 3),
#   ('VVFIN', 2),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('APPR', 1),
#   ('ADJD', 1),
#   ('$,', 1)],
#  [('$,', 6),
#   ('NN', 6),
#   ('ADJA', 3),
#   ('ADV', 3),
#   ('VVFIN', 2),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 2),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('APPR', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 17),
#   ('ADJA', 6),
#   ('$,', 4),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('$,', 6),
#   ('VVINF', 5),
#   ('ADJA', 4),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('PDS', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('VMFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 8),
#   ('$,', 4),
#   ('VVFIN', 2),
#   ('PROAV', 1),
#   ('VVPP', 1),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('PPOSAT', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('ADJA', 4),
#   ('$,', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('PPOSAT', 1),
#   ('TRUNC', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('VVINF', 3),
#   ('$,', 2),
#   ('ADJA', 2),
#   ('$(', 1),
#   ('ADV', 1),
#   ('PRELS', 1),
#   ('VVPP', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 3),
#   ('NE', 2),
#   ('VVFIN', 1),
#   ('PROAV', 1),
#   ('PWAV', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('$,', 1), ('$.', 1)],
#  [('NN', 13),
#   ('$,', 6),
#   ('PROAV', 2),
#   ('ADJD', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('PIAT', 1),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('PTKVZ', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('VVFIN', 2),
#   ('NN', 2),
#   ('$,', 1),
#   ('NE', 1),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('PIAT', 1), ('ADV', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 1), ('VMFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 10),
#   ('VVINF', 5),
#   ('$,', 4),
#   ('ADJA', 4),
#   ('ADV', 3),
#   ('VVFIN', 1),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('PIAT', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVINF', 2), ('VMFIN', 1), ('$,', 1), ('$.', 1)],
#  [('ADV', 4),
#   ('NN', 3),
#   ('APPR', 2),
#   ('$,', 2),
#   ('NE', 2),
#   ('PRELS', 1),
#   ('APPO', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 2),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('PWAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('VVINF', 2), ('ADJA', 2), ('PROAV', 1), ('$,', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 11),
#   ('$,', 2),
#   ('ADJA', 2),
#   ('$.', 2),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('VVIZU', 1),
#   ('ADJD', 1),
#   ('ADV', 1),
#   ('NE', 1)],
#  [('NN', 7), ('ADJA', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 4),
#   ('VVINF', 2),
#   ('APPR', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 6),
#   ('VVINF', 3),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('KON', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 4),
#   ('VVFIN', 2),
#   ('$,', 2),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('VVIZU', 1),
#   ('ADJD', 1)],
#  [('NN', 10),
#   ('$,', 6),
#   ('ADJA', 6),
#   ('VVINF', 3),
#   ('PROAV', 2),
#   ('VVPP', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('$.', 2), ('VVFIN', 1)],
#  [('NN', 6), ('ADJA', 2), ('ADJD', 1), ('PIAT', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VVFIN', 2),
#   ('PROAV', 1),
#   ('PTKVZ', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('PROAV', 1), ('NN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('ADJD', 2),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('PWAV', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 3),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 9), ('VVFIN', 1), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 9), ('ADJA', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 6), ('$,', 2), ('VVPP', 2), ('ADJA', 2), ('ADJD', 1), ('$.', 1)],
#  [('NN', 5), ('ADJA', 2), ('VVFIN', 1), ('$.', 1)],
#  [('ADJA', 3),
#   ('NN', 2),
#   ('ADV', 2),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('ADV', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 19),
#   ('$,', 5),
#   ('ADJA', 4),
#   ('$.', 2),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVPP', 1),
#   ('CARD', 1),
#   ('ADV', 1),
#   ('PIAT', 1),
#   ('VVINF', 1)],
#  [('NN', 13),
#   ('$,', 9),
#   ('ADJA', 7),
#   ('VVINF', 5),
#   ('ADV', 3),
#   ('APPR', 2),
#   ('VVPP', 2),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('PIAT', 1),
#   ('VVFIN', 1),
#   ('VVIZU', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 4),
#   ('$.', 2),
#   ('VMFIN', 1),
#   ('$,', 1),
#   ('TRUNC', 1),
#   ('VVFIN', 1)],
#  [('NN', 5), ('$,', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 5), ('NE', 2), ('$.', 1)],
#  [('ADJA', 4), ('NN', 3), ('$,', 2), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('VVINF', 2), ('ADJA', 1), ('APPR', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 3), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('VVINF', 3),
#   ('ADJA', 2),
#   ('VMFIN', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 4),
#   ('VVFIN', 4),
#   ('CARD', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('PTKVZ', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 3), ('VVFIN', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('$(', 2),
#   ('VVINF', 2),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('VVFIN', 2), ('$,', 1), ('NN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 4),
#   ('$,', 3),
#   ('VVINF', 1),
#   ('ADJD', 1),
#   ('VAPP', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 12),
#   ('$,', 5),
#   ('$.', 2),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('VVFIN', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('ADJD', 2),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVINF', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 16),
#   ('ADJA', 4),
#   ('$,', 2),
#   ('VVFIN', 2),
#   ('$.', 2),
#   ('CARD', 1),
#   ('KON', 1),
#   ('APPR', 1),
#   ('APPRART', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 4),
#   ('$,', 2),
#   ('ADV', 2),
#   ('VVPP', 1),
#   ('VVIZU', 1),
#   ('PWAV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('PPOSAT', 2),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('VVINF', 2),
#   ('PROAV', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('NE', 1),
#   ('NN', 1),
#   ('$.', 1)],
#  [('NN', 9), ('ADJA', 3), ('$,', 1), ('ADJD', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 8),
#   ('NE', 2),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVPP', 2),
#   ('TRUNC', 1),
#   ('PRELS', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('CARD', 4),
#   ('ADJA', 3),
#   ('NE', 2),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('VVFIN', 2),
#   ('VVINF', 2),
#   ('PROAV', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('NN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 5),
#   ('ADJA', 5),
#   ('TRUNC', 3),
#   ('ADJD', 2),
#   ('PROAV', 1),
#   ('VAFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('ADJA', 6),
#   ('$,', 2),
#   ('VVPP', 1),
#   ('VAPP', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('PIAT', 1),
#   ('PPOSAT', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 14),
#   ('$,', 5),
#   ('ADJA', 3),
#   ('VVINF', 2),
#   ('VVPP', 1),
#   ('TRUNC', 1),
#   ('ADJD', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 7), ('ADV', 4), ('$,', 2), ('ADJA', 1), ('PTKVZ', 1), ('$.', 1)],
#  [('$,', 2),
#   ('NN', 2),
#   ('ADV', 1),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('VVIZU', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('VVPP', 3),
#   ('ADV', 2),
#   ('$.', 2),
#   ('VAFIN', 2),
#   ('$,', 2),
#   ('VAPP', 1),
#   ('NE', 1),
#   ('ADJA', 1)],
#  [('NN', 3),
#   ('ADV', 2),
#   ('$,', 2),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('VVINF', 2), ('NN', 2), ('VVFIN', 1), ('PROAV', 1), ('$,', 1), ('$.', 1)],
#  [('VVINF', 2),
#   ('$,', 2),
#   ('NN', 2),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('KOUS', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('ADJA', 4),
#   ('VVINF', 2),
#   ('$.', 2),
#   ('$,', 2),
#   ('PTKVZ', 1),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('VVFIN', 1)],
#  [('ADJD', 2), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$(', 2),
#   ('$.', 2),
#   ('ADV', 2),
#   ('$,', 2),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('PIAT', 1),
#   ('CARD', 1),
#   ('VVPP', 1)],
#  [('NN', 7),
#   ('CARD', 2),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VMFIN', 1), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJD', 2),
#   ('$,', 2),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('VVPP', 2),
#   ('PTKVZ', 1),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 11),
#   ('$,', 3),
#   ('ADJA', 1),
#   ('CARD', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('$,', 5),
#   ('VVPP', 4),
#   ('NN', 4),
#   ('ADJD', 3),
#   ('PIAT', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('APPR', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('$,', 4),
#   ('ADV', 2),
#   ('ADJA', 2),
#   ('ADJD', 2),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('VVFIN', 3),
#   ('$,', 2),
#   ('CARD', 2),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('PTKVZ', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 2),
#   ('CARD', 2),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('APPR', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('ADJA', 3), ('NN', 3), ('TRUNC', 1), ('$.', 1)],
#  [('NN', 4), ('VVINF', 2), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 6), ('VVINF', 2), ('ADJA', 2), ('$,', 1), ('$.', 1)],
#  [('ADJA', 4), ('NN', 4), ('$,', 1), ('ADV', 1), ('KON', 1), ('$.', 1)],
#  [('NN', 2),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('PIAT', 1),
#   ('ADJD', 1),
#   ('PROAV', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 3), ('APPR', 1), ('ADJA', 1), ('VMFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4), ('$,', 2), ('ADJA', 1), ('VVFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADV', 3),
#   ('$(', 2),
#   ('PROAV', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('NE', 1),
#   ('$.', 1)],
#  [('NN', 7), ('VVINF', 3), ('$,', 2), ('ADV', 1), ('ADJA', 1), ('$.', 1)],
#  [('ADJD', 2), ('VVFIN', 1), ('$,', 1), ('APPR', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 4),
#   ('VVINF', 4),
#   ('VVFIN', 2),
#   ('ADV', 1),
#   ('NE', 1),
#   ('KON', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 2),
#   ('TRUNC', 1),
#   ('ADJA', 1),
#   ('VVIZU', 1),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 3),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('APPR', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVPP', 1), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 2),
#   ('VVFIN', 2),
#   ('NE', 1),
#   ('ADJA', 1),
#   ('APPR', 1),
#   ('ADV', 1),
#   ('PTKVZ', 1),
#   ('$.', 1)],
#  [('NN', 5), ('VVFIN', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 8),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('NE', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3), ('$,', 3), ('VVFIN', 2), ('ADJD', 2), ('VVIZU', 1), ('$.', 1)],
# ...
#   ('ADJA', 3),
#   ('NE', 2),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6), ('VVINF', 2), ('ADV', 2), ('ADJD', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 6), ('ADJA', 2), ('VVFIN', 1), ('TRUNC', 1), ('$.', 1)],
#  [('NN', 15),
#   ('$,', 7),
#   ('ADJA', 6),
#   ('ADJD', 3),
#   ('APPR', 2),
#   ('VVINF', 1),
#   ('VVIZU', 1),
#   ('KON', 1),
#   ('VVFIN', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 9), ('ADJA', 4), ('ADV', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 8), ('$,', 4), ('VVINF', 2), ('ADJA', 2), ('PTKVZ', 1), ('$.', 1)],
#  [('NN', 6), ('$,', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 2),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('$,', 1),
#   ('VVINF', 1),
#   ('VAFIN', 1),
#   ('VVPP', 1)],
#  [('NN', 5), ('CARD', 2), ('$.', 2), ('ADV', 1), ('ADJA', 1), ('ADJD', 1)],
#  [('NN', 3), ('$.', 1)],
#  [('$,', 3),
#   ('NN', 2),
#   ('ADV', 2),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('VVPP', 2),
#   ('VVIZU', 2),
#   ('APPR', 1),
#   ('CARD', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 6), ('ADJA', 2), ('ADJD', 1), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 5),
#   ('CARD', 2),
#   ('VVFIN', 1),
#   ('TRUNC', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('ADJD', 2), ('$.', 1)],
#  [('NN', 2), ('ADJD', 1), ('VVFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 4), ('APPR', 1), ('CARD', 1), ('ADJA', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 7), ('CARD', 2), ('NE', 2), ('ADJA', 1), ('$.', 1)],
#  [('NN', 3), ('PROAV', 1), ('VMFIN', 1), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 13),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('PROAV', 1),
#   ('APPR', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('TRUNC', 1)],
#  [('NN', 4), ('ADJD', 1), ('VVFIN', 1), ('CARD', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 5),
#   ('ADJD', 2),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('$,', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADV', 2), ('ADJD', 1), ('$,', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 3), ('ADJA', 1), ('VMFIN', 1), ('ADJD', 1), ('$.', 1)],
#  [('PIS', 1), ('ADJA', 1), ('NN', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 4), ('ADJA', 1), ('ADJD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJD', 2),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('$,', 2),
#   ('NN', 2),
#   ('PTKVZ', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('$,', 4), ('VVFIN', 3), ('NN', 3), ('ADJA', 2), ('PROAV', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('PROAV', 1),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3), ('$,', 2), ('VVPP', 2), ('ADJA', 1), ('$.', 1)],
#  [('NN', 3), ('$,', 2), ('ADJD', 2), ('ADJA', 2), ('VMFIN', 1), ('$.', 1)],
#  [('NN', 6), ('VMFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 11), ('$,', 3), ('VVPP', 2), ('ADJA', 2), ('VVINF', 1), ('$.', 1)],
#  [('NN', 10),
#   ('ADJA', 4),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('VVIZU', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('ADJD', 2),
#   ('VVPP', 2),
#   ('ADV', 2),
#   ('KOUS', 1),
#   ('TRUNC', 1),
#   ('CARD', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4), ('$.', 2), ('$,', 1), ('ADJA', 1), ('ADJD', 1)],
#  [('NN', 5), ('$,', 1), ('VVINF', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 3),
#   ('ADV', 3),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('VAFIN', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVINF', 1), ('$,', 1), ('KON', 1), ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 3),
#   ('ADJD', 2),
#   ('ADV', 2),
#   ('VMFIN', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('KON', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('ADJD', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('KON', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('$(', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('ADJA', 2), ('NN', 2), ('VMFIN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 4),
#   ('NE', 1),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('ADJA', 3), ('NN', 3), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 4),
#   ('VVFIN', 1),
#   ('PIS', 1),
#   ('$,', 1),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVFIN', 1), ('PPOSAT', 1), ('PTKVZ', 1), ('$.', 1)],
#  [('ADJA', 3),
#   ('NN', 2),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('ADJA', 3),
#   ('VVINF', 2),
#   ('VMFIN', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 3), ('$.', 1)],
#  [('NN', 7), ('ADJA', 3), ('VVFIN', 2), ('VMFIN', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 8), ('ADJA', 4), ('$,', 2), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 6),
#   ('$,', 2),
#   ('VVIZU', 2),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 2), ('ADV', 1), ('VMFIN', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 5), ('ADJA', 3), ('ADJD', 1), ('VVINF', 1), ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 4), ('VVPP', 3), ('$,', 2), ('ADV', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 7),
#   ('VVINF', 3),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 4),
#   ('VVFIN', 3),
#   ('ADJA', 3),
#   ('ADV', 2),
#   ('NE', 1),
#   ('PIAT', 1),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('VAFIN', 1),
#   ('VVPP', 1),
#   ('VAPP', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('NE', 2),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 2),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('ADV', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1)],
#  [('NN', 3),
#   ('NE', 3),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('KON', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('ADJA', 4),
#   ('$,', 4),
#   ('ADV', 2),
#   ('ADJD', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('VVINF', 1), ('NN', 1), ('$.', 1)],
#  [('NN', 2), ('VVPP', 1), ('$,', 1), ('VVINF', 1), ('VMFIN', 1), ('$.', 1)],
#  [('NN', 7), ('$.', 2), ('ADJA', 1), ('VVPP', 1), ('CARD', 1), ('$,', 1)],
#  [('NN', 5), ('VVFIN', 1), ('PIAT', 1), ('$.', 1)],
#  [('NN', 3), ('ADV', 2), ('VVFIN', 1), ('ADJD', 1), ('ADJA', 1), ('$.', 1)],
#  [('ADV', 5),
#   ('$,', 4),
#   ('NN', 3),
#   ('VVINF', 2),
#   ('VVIZU', 1),
#   ('VVPP', 1),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$,', 2),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('PIAT', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 4),
#   ('ADJA', 3),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('ADV', 3),
#   ('NN', 3),
#   ('$,', 2),
#   ('ADJD', 2),
#   ('VVINF', 1),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 2),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 2), ('VVINF', 1), ('ADV', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 5),
#   ('VVINF', 3),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 4), ('VVINF', 1), ('ADV', 1), ('CARD', 1), ('$.', 1)],
#  [('NN', 2), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('ADJD', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('ADV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 8), ('$,', 2), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('VVPP', 1), ('$,', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 2), ('VMFIN', 1), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 2), ('VVFIN', 1), ('$,', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 2),
#   ('VMFIN', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 2), ('$,', 1), ('PWAV', 1), ('$.', 1)],
#  [('NN', 5), ('ADV', 3), ('$,', 2), ('VVFIN', 2), ('ADJD', 1), ('$.', 1)],
#  [('NN', 2), ('NE', 1), ('ADV', 1), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 4),
#   ('VVINF', 3),
#   ('ADJD', 2),
#   ('ADJA', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('PIAT', 2),
#   ('ADV', 1),
#   ('$,', 1),
#   ('VVINF', 1),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 5),
#   ('VVINF', 4),
#   ('$,', 4),
#   ('ADJD', 3),
#   ('$.', 2),
#   ('VVFIN', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVPP', 1)],
#  [('NN', 2), ('PIAT', 1), ('APPR', 1), ('$,', 1), ('$.', 1)],
#  [('NN', 4), ('VVFIN', 2), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 11),
#   ('$,', 3),
#   ('$.', 2),
#   ('NE', 2),
#   ('VVFIN', 1),
#   ('APPR', 1),
#   ('ADJA', 1),
#   ('ADV', 1),
#   ('ADJD', 1)],
#  [('NN', 7), ('ADJA', 2), ('APPR', 1), ('NE', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('PIAT', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('ADJD', 2),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('$,', 1),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('ADJA', 5),
#   ('ADJD', 2),
#   ('$,', 1),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('APPR', 1),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 3), ('ADJA', 2), ('ADJD', 1), ('$.', 1)],
#  [('NN', 7), ('ADJA', 2), ('ADJD', 1), ('$(', 1), ('$.', 1)],
#  [('NN', 2), ('VVINF', 1), ('$,', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('VVFIN', 1), ('APPR', 1), ('$.', 1)],
#  [('ADJA', 2), ('NN', 2), ('$.', 1)],
#  [('NN', 4), ('$,', 1), ('VMFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 7),
#   ('VVINF', 5),
#   ('$,', 4),
#   ('ADJA', 2),
#   ('VMFIN', 2),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5), ('VVINF', 3), ('$,', 3), ('ADV', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 4), ('$,', 1), ('ADJA', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 6), ('$,', 3), ('ADJA', 3), ('VMFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 4),
#   ('$,', 2),
#   ('VVINF', 2),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('KON', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('ADJA', 2),
#   ('NN', 2),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('$,', 1),
#   ('VVIZU', 1),
#   ('$.', 1)],
#  [('NN', 6), ('ADJA', 2), ('$,', 1), ('$.', 1)],
#  [('NE', 4),
#   ('NN', 4),
#   ('$,', 2),
#   ('ADJA', 2),
#   ('VVPP', 2),
#   ('ADJD', 1),
#   ('VAFIN', 1),
#   ('ADV', 1),
#   ('$.', 1)],
#  [('NN', 4), ('ADJA', 2), ('NE', 1), ('VAFIN', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 3),
#   ('ADV', 2),
#   ('NE', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('APPR', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('NE', 3),
#   ('PTKVZ', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVFIN', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 8),
#   ('CARD', 2),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 4),
#   ('$,', 3),
#   ('NE', 3),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('ADJA', 2), ('NN', 2), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 3), ('VVINF', 1), ('PTKVZ', 1), ('$.', 1)],
#  [('ADJA', 1), ('NN', 1), ('NE', 1), ('$.', 1)],
#  [('NN', 7),
#   ('VMFIN', 1),
#   ('ADJD', 1),
#   ('VVINF', 1),
#   ('$,', 1),
#   ('VVFIN', 1),
#   ('$.', 1)],
#  [('NN', 9),
#   ('ADJA', 3),
#   ('$,', 2),
#   ('$.', 2),
#   ('ADV', 1),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('VVINF', 1)],
#  [('NN', 10),
#   ('$,', 6),
#   ('ADJA', 5),
#   ('VVFIN', 2),
#   ('VMFIN', 2),
#   ('ADV', 2),
#   ('NE', 1),
#   ('ADJD', 1),
#   ('PROAV', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 3), ('VVINF', 3), ('$,', 2), ('$.', 2), ('ADV', 1), ('ADJA', 1)],
#  [('NN', 7),
#   ('NE', 2),
#   ('$.', 2),
#   ('ADJA', 2),
#   ('$,', 2),
#   ('ADV', 2),
#   ('VVFIN', 1),
#   ('VVINF', 1)],
#  [('NN', 4), ('PIAT', 1), ('ADJA', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 8),
#   ('VVINF', 3),
#   ('$,', 3),
#   ('NE', 2),
#   ('VVFIN', 2),
#   ('$.', 2),
#   ('PROAV', 2),
#   ('VMFIN', 1),
#   ('ADJA', 1)],
#  [('NN', 5),
#   ('CARD', 1),
#   ('VVPP', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 5), ('VVINF', 2), ('PPOSAT', 1), ('$,', 1), ('ADJD', 1), ('$.', 1)],
#  [('NN', 6), ('VVINF', 2), ('VMFIN', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 10),
#   ('$,', 6),
#   ('ADJA', 3),
#   ('VVPP', 2),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVIZU', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('VVPP', 2),
#   ('$,', 2),
#   ('NN', 2),
#   ('VMFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('ADJA', 2), ('VVINF', 1), ('$,', 1), ('NN', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 7),
#   ('$,', 2),
#   ('VVINF', 2),
#   ('VVFIN', 1),
#   ('ADJA', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('ADJA', 2), ('$,', 1), ('NN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 4),
#   ('VVINF', 2),
#   ('ADV', 2),
#   ('FM', 2),
#   ('VVPP', 1),
#   ('ADJD', 1),
#   ('APPR', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 4), ('$,', 2), ('NE', 1), ('VVPP', 1), ('$.', 1)],
#  [('VVFIN', 1), ('$,', 1), ('ADJA', 1), ('NN', 1), ('VVIZU', 1), ('$.', 1)],
#  [('NN', 5),
#   ('$,', 3),
#   ('VVFIN', 2),
#   ('NE', 1),
#   ('VVINF', 1),
#   ('ADJD', 1),
#   ('APPR', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('$.', 2),
#   ('ADV', 2),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('NE', 1),
#   ('$,', 1),
#   ('ADJA', 1),
#   ('VVPP', 1)],
#  [('NN', 3),
#   ('$,', 2),
#   ('ADJA', 1),
#   ('VMFIN', 1),
#   ('ADV', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('ADJD', 3),
#   ('ADJA', 2),
#   ('$.', 2),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('VVIZU', 1),
#   ('VVINF', 1),
#   ('ADV', 1)],
#  [('NN', 6),
#   ('$,', 5),
#   ('VVPP', 3),
#   ('VVINF', 2),
#   ('ADJA', 2),
#   ('$.', 2),
#   ('VMFIN', 1),
#   ('NE', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1)],
#  [('NN', 8),
#   ('$,', 3),
#   ('ADJA', 2),
#   ('VVINF', 2),
#   ('ADV', 1),
#   ('PROAV', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5), ('$,', 2), ('ADV', 2), ('CARD', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 2),
#   ('ADJD', 1),
#   ('$,', 1),
#   ('PWS', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 10),
#   ('$,', 7),
#   ('ADJA', 5),
#   ('ADV', 2),
#   ('ADJD', 2),
#   ('VVFIN', 2),
#   ('VMFIN', 2),
#   ('VVINF', 1),
#   ('VVPP', 1),
#   ('VAFIN', 1),
#   ('$.', 1)],
#  [('NN', 7),
#   ('$,', 3),
#   ('ADJA', 3),
#   ('ADV', 1),
#   ('ADJD', 1),
#   ('VVFIN', 1),
#   ('VVINF', 1),
#   ('APPR', 1),
#   ('$.', 1)],
#  [('ADJD', 5),
#   ('$,', 5),
#   ('VVINF', 3),
#   ('NN', 3),
#   ('ADV', 1),
#   ('VVFIN', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJD', 2), ('NE', 1), ('$,', 1), ('ADJA', 1), ('$.', 1)],
#  [('VVINF', 3), ('PROAV', 3), ('$,', 3), ('NN', 2), ('ADJA', 1), ('$.', 1)],
#  [('NN', 6),
#   ('$,', 2),
#   ('VVINF', 2),
#   ('VVFIN', 2),
#   ('ADV', 2),
#   ('PROAV', 1),
#   ('ADJA', 1),
#   ('$.', 1)],
#  [('NN', 4), ('$,', 1), ('VVINF', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 2),
#   ('VVFIN', 2),
#   ('$(', 1),
#   ('ADV', 1),
#   ('APPR', 1),
#   ('$,', 1),
#   ('VMFIN', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 4),
#   ('ADJD', 3),
#   ('$,', 2),
#   ('VVINF', 2),
#   ('PROAV', 1),
#   ('$.', 1)],
#  [('ADV', 2), ('VMFIN', 1), ('PROAV', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 2), ('VVINF', 1), ('$.', 1)],
#  [('NN', 6),
#   ('ADJA', 3),
#   ('VVFIN', 1),
#   ('$,', 1),
#   ('NE', 1),
#   ('ADV', 1),
#   ('VAPP', 1),
#   ('VVINF', 1),
#   ('VMFIN', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADJA', 1), ('KON', 1), ('VVPP', 1), ('$.', 1)],
#  [('ADV', 2), ('VVINF', 1), ('$.', 1)],
#  [('NN', 8), ('ADJA', 5), ('$(', 2), ('ADJD', 1), ('VVFIN', 1), ('$.', 1)],
#  [('NN', 8),
#   ('ADJA', 4),
#   ('ADV', 2),
#   ('VVINF', 2),
#   ('$,', 2),
#   ('PIS', 1),
#   ('ADJD', 1),
#   ('$.', 1)],
#  [('NN', 5), ('ADV', 1), ('VVFIN', 1), ('ADJA', 1), ('$.', 1)],
#  [('NN', 3), ('ADJA', 3), ('VVINF', 1), ('ADV', 1), ('VVPP', 1), ('$.', 1)],
#  [('NN', 13),
#   ('ADJA', 5),
#   ('VVFIN', 3),
#   ('$,', 2),
#   ('VVINF', 1),
#   ('KON', 1),
#   ('PIAT', 1),
#   ('APPR', 1),
#   ('VVPP', 1),
#   ('$.', 1)],
#  [('NN', 3),
#   ('ADJD', 2),
#   ('PROAV', 1),
#   ('PPOSAT', 1),
#   ('ADJA', 1),
#   ('$,', 1),
#   ('VVINF', 1),
#   ('$.', 1)],
#  [('NN', 12), ('$,', 3), ('ADJA', 3), ('VVFIN', 1), ('VVINF', 1), ('$.', 1)],
#  [('NN', 3), ('PROAV', 1), ('VVPP', 1), ('$.', 1)],
#  ...]

# %%
# ##show problems of question and exclamations marks
# pd.set_option('display.max_colwidth', 500)
# df[2476:2477]
# df[2839:2840]
# df[3091:3092]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          English  \
# 3091  Could the Commission say whether the Greek Government has made any specific commitments on how to tackle the problems of youth and long-term unemployment, and what these commitments are? Has the government legislated for and put into place a suitable system for pinpointing, recording and monitoring fluctuations in unemployment, or are most of the measures perhaps still limited to counting those out of work?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    German
# 3091  Kann die Kommission mitteilen, ob die griechische Regierung konkrete Verpflichtungen B und welche B hinsichtlich der Art und Weise übernommen hat, wie das Problem der Jugendarbeitslosigkeit und der Langzeitarbeitslosigkeit zu bewältigen ist und ob sie ein geeignetes System zur Lokalisierung, Registrierung und Kontrolle der Fluktuation der Arbeitslosigkeit festgesetzt hat und umsetzt oder ob sich die meisten Maßnahmen weiterhin auf die Aufzählung der Arbeitslosigkeit beschränken?

# %%
# Out:
# FreqDist({'NOUN': 2, '.': 2, 'ADJ': 1})

# %%
# Out:
#                                              English  \
# 1  I declare resumed the session of the European ...
#
#                                               German
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
